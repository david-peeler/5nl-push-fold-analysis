# %%
############
# Enviroment set-up
############
import string
import os
import re
from pprint import pprint
from collections import defaultdict
import postgres
import poker
from IPython.core.display import display, HTML

position_mapping = {
    "Dealer": "BU",
    "Small Blind": "SB",
    "Big Blind": 'BB',
    "UTG": "UTG",
    "UTG+1": 'LJ',
    "UTG+2": 'HJ'
}
# Out:
# C:\Users\David\AppData\Local\Temp\ipykernel_15880\3874190313.py:11: DeprecationWarning: Importing display from IPython.core.display is deprecated since IPython 7.14, please import from IPython display
#   from IPython.core.display import display, HTML

# %%
HTML("""
<style>
   td {
      /* Make cells same width and height and centered */
      width: 25px;
      height: 25px;
      text-align: center;
      vertical-align: middle;
   }
   td.pair {
      background: #aaff9f;
   }
   td.offsuit {
      background: #bbced3;
   }
   td.suited {
      background: #e37f7d;
   }
</style>
""")
# Out:
# <style>
#    td {
#       /* Make cells same width and height and centered */
#       width: 25px;
#       height: 25px;
#       text-align: center;
#       vertical-align: middle;
#    }
#    td.pair {
#       background: #aaff9f;
#    }
#    td.offsuit {
#       background: #bbced3;
#    }
#    td.suited {
#       background: #e37f7d;
#    }
# </style>

# %% [markdown]
# # Ignition Hand Parsing
#
# Couple things:
#    - Processes iggy hands in bulk per table (per file)
#    - No post flop action: Board = None
#    - Board is always 5 len otherwise; so no turn action means 2 empty strings after
#        - Just how iggy does it...
#    - Hand is a tuple that's added to each player's entry

# %%
def find_pos(line):
    pos = None
    for key in position_mapping:
        if key in line:
            pos = position_mapping[key]
    if pos:
        return pos

def get_bb(line, bb):
    return round(float(re.findall("\$\d+(?:\.\d+)?", line)[0][1:])/bb)

# %%
############
# Parse Ignition hands
# 
# Ignition hands are broken into large files; each file is a series of hands that belong to that table
############

def get_stakes(hand):
    sb, bb = None, None
    for line in hand:
        if ': Small Blind $' in line:
            sb = float(re.findall("\$\d+(?:\.\d+)?", line)[0][1:])
        if ': Big blind $' in line:
            bb = float(re.findall("\$\d+(?:\.\d+)?", line)[0][1:])
            
        if sb and bb:
            break
    
    return ((sb, bb), bb)
            

def get_players(hand, bb):
    temp_dict = defaultdict(list)
    player_list = []
    
    for line in hand:
        if "in chips" in line:
            bigs = get_bb(line, bb)
            pos = find_pos(line)
            player = 'Hero' if "ME" in line else ''
            
            temp_dict[pos] = [pos, player, bigs]
            
        if "Card dealt" in line:
            cards = tuple(re.findall("\[(.*?)\]", line)[0].split(" "))
            if cards[0] == 'ME':
                cards = tuple(re.findall("\[(.*?)\]", line)[1].split(" "))
            temp_dict[find_pos(line)].append(cards)
            
            
    return list(temp_dict.values())
                
                

def get_board(hand):
    for line in hand:
        if 'Board' in line:
            return re.findall("\[(.*?)\]", line)[0].split(" ")
            
def get_action(hand, bb):
    action = []
    
    street_action = []
    for line in hand:
        if 'Calls' in line:
            street_action.append(find_pos(line) + "c" + str(get_bb(line, bb)))
        if 'Raises' in line or 'raise' in line:
            street_action.append(find_pos(line) + "r" + str(get_bb(line, bb)))
            continue
        if 'Folds' in line:
            street_action.append(find_pos(line) + "f")
        if 'Checks' in line:
            street_action.append(find_pos(line) + "x")
        if 'Bets' in line or 'All-in' in line:
            street_action.append(find_pos(line) + "b" + str(get_bb(line, bb)))
        
        if "FLOP" in line or "TURN" in line or "RIVER" in line:
            if len(street_action) > 0:
                action.append(street_action) 
            street_action = []
        if "SUMMARY" in line:
            if len(street_action) > 0:
                action.append(street_action)
            break
            
    return action

def get_winner(hand):
    winners = []
    wsd = None
    for line in hand[::-1]:
        if 'Hand result' in line or re.findall("\$\d+(?:\.\d+)?", line):
            winner = find_pos(line)
            wsd = False if "Does not show" in line else True
            winners.append(winner)
        
        if "Total Pot" in line or "Hand result" in line:
            if not wsd:
                wsd = False
            break
            
    return (winners, wsd)
    
            

def get_hand_number(hand):
    return re.findall("\d+", hand[0])[0]


def build_hand(file_name):
    #Builds all hands for given file
    file = open(file_name, "r").read()
    hands = re.split(r'\n{2,}', file)
    hands = hands[:len(hands)-1]

    ret = {}
    for hand in hands:
        hand = re.split(r'\n{1,}', hand)
        
        hand_dict = {}
        hand_dict['Stakes'], bb = get_stakes(hand) 
        hand_dict['Players'] = get_players(hand, bb)
        hand_dict['Board'] = get_board(hand)
        hand_dict['Action'] = get_action(hand, bb)
        hand_dict['Winner'], hand_dict["WTSD"] = get_winner(hand)
        ret[get_hand_number(hand)] = hand_dict
    
    return ret


####
# TEST
####
#for root, dirs, files in os.walk(r"C:\Users\David\Ignition Casino Poker\Hand History\580402808201", topdown=False):0
#    for file in files:
#        print(file)
#        pprint(build_hand(root + "\\" + file))

# %% [markdown]
# # 5nl P/F Analysis

# %%
hands=[]

for root, dirs, files in os.walk(r"C:\Users\David\Ignition Casino Poker\Hand History\580402808201", topdown=False):
    for file in files:
        if "ZonePoker" in file and ".05" in file:
            hands.append(build_hand(root + "\\" + file))

# %%
sum_hands = 0
for i in hands:
    sum_hands+=len(i.keys())

print("Number of 5nl hands:", sum_hands)
# Out:
# Number of 5nl hands: 2080

# %%
pprint(hands)
# Out:
# [{'4474450410': {'Action': [['UTGf',
#                              'LJc1',
#                              'HJf',
#                              'BUf',
#                              'SBf',
#                              'BBr50',
#                              'LJf']],
#                  'Board': None,
#                  'Players': [['BB', 'Hero', 51, ('Kc', 'As')],
#                              ['UTG', '', 99, ('4h', '2d')],
#                              ['LJ', '', 50, ('8d', 'Jh')],
#                              ['HJ', '', 127, ('Qs', '2c')],
#                              ['BU', '', 224, ('Jc', '6c')],
#                              ['SB', '', 103, ('3c', '7c')]],
#                  'Stakes': (0.02, 0.05),
#                  'WTSD': True,
#                  'Winner': ['BB', 'BB']},
#   '4474450562': {'Action': [['UTGf', 'LJf', 'HJf', 'BUr3', 'SBf', 'BBc2'],
#                             ['BBb1', 'BUc1'],
#                             ['BBb1', 'BUf']],
#                  'Board': None,
#                  'Players': [['BB', '', 157, ('Ac', '5c')],
#                              ['UTG', '', 63, ('4h', 'Jh')],
#                              ['LJ', '', 99, ('6s', 'Tc')],
#                              ['HJ', '', 122, ('Ts', 'Qs')],
#                              ['BU', '', 144, ('Ks', '3h')],
#                              ['SB', 'Hero', 100, ('4s', '6h')]],
#                  'Stakes': (0.02, 0.05),
#                  'WTSD': True,
#                  'Winner': ['BB']},
#   '4474450601': {'Action': [['UTGf', 'LJf', 'HJf', 'BUf', 'SBf']],
#                  'Board': None,
#                  'Players': [['SB', '', 99, ('6c', '2s')],
#                              ['BB', '', 224, ('7s', 'Jc')],
#                              ['UTG', '', 109, ('Jh', '8s')],
#                              ['LJ', '', 270, ('Qh', '9h')],
#                              ['HJ', 'Hero', 100, ('5c', '5s')],
#                              ['BU', '', 182, ('3d', '9c')]],
#                  'Stakes': (0.02, 0.05),
#                  'WTSD': True,
#                  'Winner': ['BB', None]},
#   '4474450674': {'Action': [['UTGf', 'LJf', 'HJf', 'BUf', 'SBr3', 'BBc2'],
#                             ['SBb3', 'BBc3'],
#                             ['SBx', 'BBx'],
#                             ['SBx', 'BBx']],
#                  'Board': None,
#                  'Players': [['BU', '', 173, ('9d', 'Kh')],
#                              ['SB', '', 100, ('Qs', '8s')],
#                              ['BB', '', 90, ('9h', 'Qh')],
#                              ['UTG', '', 109, ('4d', '8h')],
#                              ['LJ', 'Hero', 100, ('3d', '4h')],
#                              ['HJ', '', 123, ('Jd', '3s')]],
#                  'Stakes': (0.02, 0.05),
#                  'WTSD': True,
#                  'Winner': ['SB']},
#   '4474450718': {'Action': [['UTGf', 'LJf', 'HJf', 'BUf', 'SBc1', 'BBx'],
#                             ['SBb1', 'BBf']],
#                  'Board': None,
#                  'Players': [['BB', 'Hero', 100, ('6s', '8s')],
#                              ['UTG', '', 109, ('Ks', '9d')],
#                              ['LJ', '', 104, ('2d', '3h')],
#                              ['HJ', '', 93, ('Jh', '8c')],
#                              ['BU', '', 107, ('8d', '9c')],
#                              ['SB', '', 173, ('5c', 'Kc')]],
#                  'Stakes': (0.02, 0.05),
#                  'WTSD': True,
#                  'Winner': [None, 'SB']},
#   '4474450757': {'Action': [['UTGr3',
#                              'LJf',
#                              'HJc3',
#                              'BUf',
#                              'SBr15',
#                              'BBf',
#                              'UTGc12',
#                              'HJf'],
#                             ['SBb10', 'UTGc10'],
#                             ['SBx', 'UTGx'],
#                             ['SBb73', 'UTGf']],
#                  'Board': ['Ts', 'Ah', '4c', 'Kd', '6c'],
#                  'Players': [['BU', '', 689, ('5d', 'Kh')],
#                              ['SB', 'Hero', 99, ('9h', '9s')],
#                              ['BB', '', 109, ('Jd', '6h')],
#                              ['UTG', '', 101, ('7s', '7d')],
#                              ['LJ', '', 88, ('7h', '5c')],
#                              ['HJ', '', 51, ('As', '3s')]],
#                  'Stakes': (0.02, 0.05),
#                  'WTSD': True,
#                  'Winner': ['SB', None]}},
#  {'4474450420': {'Action': [['UTGf', 'LJf', 'HJf', 'BUf', 'SBr2', 'BBf']],
#                  'Board': None,
#                  'Players': [['BB', 'Hero', 51, ('Ac', '5d')],
#                              ['UTG', '', 50, ('6c', '7s')],
#                              ['LJ', '', 126, ('Th', '5h')],
#                              ['HJ', '', 111, ('Kc', '8s')],
#                              ['BU', '', 40, ('Qs', 'Td')],
#                              ['SB', '', 688, ('Kh', 'Tc')]],
#                  'Stakes': (0.02, 0.05),
#                  'WTSD': True,
#                  'Winner': ['SB', None]},
#   '4474450546': {'Action': [['UTGf',
#                              'LJf',
#                              'HJf',
#                              'BUf',
#                              'SBr3',
#                              'BBr4',
#                              'SBr9',
#                              'BBr146',
#                              'SBc139']],
#                  'Board': None,
#                  'Players': [['UTG', '', 224, ('Qh', '7s')],
#                              ['LJ', '', 99, ('2s', 'Kd')],
#                              ['HJ', '', 174, ('Ks', '8h')],
#                              ['BU', 'Hero', 50, ('8d', 'Jd')],
#                              ['SB', '', 206, ('Ad', 'As')],
#                              ['BB', '', 151, ('9s', '9h')]],
#                  'Stakes': (0.02, 0.05),
#                  'WTSD': True,
#                  'Winner': ['SB']},
#   '4474450576': {'Action': [['UTGf', 'LJf', 'HJf', 'BUf', 'SBf']],
#                  'Board': None,
#                  'Players': [['SB', '', 104, ('7d', '6s')],
#                              ['BB', '', 49, ('Qh', '5d')],
#                              ['UTG', '', 689, ('Ks', '8c')],
#                              ['LJ', '', 117, ('4c', '3s')],
#                              ['HJ', '', 90, ('Qc', '3h')],
#                              ['BU', 'Hero', 50, ('7s', 'Td')]],
#                  'Stakes': (0.02, 0.05),
#                  'WTSD': True,
#                  'Winner': ['BB']},
#   '4474450621': {'Action': [['UTGr2', 'LJf', 'HJc2', 'BUf', 'SBf', 'BBf'],
#                             ['UTGb1', 'HJc1'],
#                             ['UTGb2', 'HJr8', 'UTGr13', 'HJc8']],
#                  'Board': None,
#                  'Players': [['SB', '', 121, ('Jc', '8d')],
#                              ['BB', '', 224, ('7d', '5c')],
#                              ['UTG', '', 18, ('Jd', 'Jh')],
#                              ['LJ', '', 134, ('3h', 'Ad')],
#                              ['HJ', '', 111, ('Ts', 'Qs')],
#                              ['BU', 'Hero', 50, ('8h', 'Ah')]],
#                  'Stakes': (0.02, 0.05),
#                  'WTSD': True,
#                  'Winner': ['HJ']},
#   '4474450711': {'Action': [['UTGf',
#                              'LJf',
#                              'HJf',
#                              'BUr3',
#                              'SBf',
#                              'BBr11',
#                              'BUc9'],
#                             ['BBb7', 'BUc7'],
#                             ['BBx', 'BUx'],
#                             ['BBx', 'BUx']],
#                  'Board': None,
#                  'Players': [['BU', '', 134, ('Tc', 'Th')],
#                              ['SB', 'Hero', 50, ('5d', '9h')],
#                              ['BB', '', 121, ('Jd', 'Qc')],
#                              ['UTG', '', 40, ('7s', '2h')],
#                              ['LJ', '', 182, ('7h', '9s')],
#                              ['HJ', '', 117, ('Jh', '4c')]],
#                  'Stakes': (0.02, 0.05),
#                  'WTSD': True,
#                  'Winner': ['BB']},
#   '4474450749': {'Action': [['UTGf', 'LJf', 'HJr2', 'BUf', 'SBf', 'BBf']],
#                  'Board': None,
#                  'Players': [['SB', '', 99, ('4h', 'Qh')],
#                              ['BB', '', 123, ('3d', '8c')],
#                              ['UTG', 'Hero', 50, ('Th', 'Kh')],
#                              ['LJ', '', 40, ('7h', 'Jc')],
#                              ['HJ', '', 49, ('Tc', '8s')],
#                              ['BU', '', 223, ('3s', 'Ad')]],
#                  'Stakes': (0.02, 0.05),
#                  'WTSD': True,
#                  'Winner': ['HJ', None]},
#   '4474450806': {'Action': [['UTGf',
#                              'LJf',
#                              'HJf',
#                              'BUr3',
#                              'SBr11',
#                              'BBr49',
#                              'BUf',
#                              'SBf']],
#                  'Board': None,
#                  'Players': [['SB', '', 97, ('Ah', 'Td')],
#                              ['BB', 'Hero', 50, ('9s', '9c')],
#                              ['UTG', '', 88, ('5s', 'Qc')],
#                              ['LJ', '', 114, ('3s', '8c')],
#                              ['HJ', '', 73, ('Qh', '4c')],
#                              ['BU', '', 100, ('7c', 'Th')]],
#                  'Stakes': (0.02, 0.05),
#                  'WTSD': True,
#                  'Winner': ['BB']},
#   '4474451075': {'Action': [['UTGf', 'LJf', 'HJf', 'BUf', 'SBr63', 'BBf']],
#                  'Board': None,
#                  'Players': [['SB', 'Hero', 64, ('Kh', 'Qs')],
#                              ['BB', '', 34, ('8c', 'Kd')],
#                              ['UTG', '', 113, ('3d', '6c')],
#                              ['LJ', '', 112, ('8h', '2c')],
#                              ['HJ', '', 93, ('6h', '8d')],
#                              ['BU', '', 97, ('4s', 'Tc')]],
#                  'Stakes': (0.02, 0.05),
#                  'WTSD': True,
#                  'Winner': ['SB']}},
#  {'4474452163': {'Action': [['UTGf', 'LJr3', 'HJf', 'BUc3', 'SBf', 'BBf'],
#                             ['LJx', 'BUx'],
#                             ['LJx', 'BUx'],
#                             ['LJx', 'BUx']],
#                  'Board': ['Kh', '4h', 'Qh', '8h', '9h'],
#                  'Players': [['SB', '', 133, ('Kd', '7h')],
#                              ['BB', 'Hero', 50, ('Td', 'Ah')],
#                              ['UTG', '', 61, ('3h', '8d')],
#                              ['LJ', '', 106, ('Ts', 'Qs')],
#                              ['HJ', '', 180, ('7s', '4s')],
#                              ['BU', '', 159, ('8s', '8c')]],
#                  'Stakes': (0.02, 0.05),
#                  'WTSD': True,
#                  'Winner': ['BU', 'LJ', None]},
#   '4474452333': {'Action': [['UTGf', 'LJf', 'HJf', 'BUr3', 'SBc3', 'BBc2'],
#                             ['SBx', 'BBx', 'BUb6', 'SBf', 'BBc6'],
#                             ['BBx', 'BUx'],
#                             ['BBb21', 'BUc21']],
#                  'Board': ['3s', 'Ks', 'Qd', 'Kd', '9s'],
#                  'Players': [['LJ', 'Hero', 49, ('Qc', '8d')],
#                              ['HJ', '', 157, ('8c', '2h')],
#                              ['BU', '', 118, ('Jd', 'Tc')],
#                              ['SB', '', 625, ('As', '6d')],
#                              ['BB', '', 78, ('Td', 'Jc')],
#                              ['UTG', '', 99, ('4c', 'Ah')]],
#                  'Stakes': (0.02, 0.05),
#                  'WTSD': True,
#                  'Winner': ['BB', 'BU', None]},
#   '4474452392': {'Action': [['UTGf', 'LJf', 'HJr3', 'BUf', 'SBf', 'BBf']],
#                  'Board': None,
#                  'Players': [['SB', 'Hero', 49, ('Tc', 'Kh')],
#                              ['BB', '', 151, ('2h', '8s')],
#                              ['UTG', '', 147, ('Qs', '7d')],
#                              ['LJ', '', 54, ('5d', '4c')],
#                              ['HJ', '', 158, ('7h', '8h')],
#                              ['BU', '', 112, ('6c', 'Qd')]],
#                  'Stakes': (0.02, 0.05),
#                  'WTSD': True,
#                  'Winner': ['HJ', None]},
#   '4474452431': {'Action': [['UTGf', 'LJf', 'HJf', 'BUc1', 'SBf', 'BBx'],
#                             ['BBx', 'BUx'],
#                             ['BBx', 'BUb1', 'BBf']],
#                  'Board': None,
#                  'Players': [['UTG', '', 38, ('6d', 'Js')],
#                              ['LJ', 'Hero', 49, ('9s', '2c')],
#                              ['HJ', '', 117, ('4h', '8c')],
#                              ['BU', '', 54, ('6h', 'Ks')],
#                              ['SB', '', 150, ('3d', '5s')],
#                              ['BB', '', 180, ('8h', '6s')]],
#                  'Stakes': (0.02, 0.05),
#                  'WTSD': True,
#                  'Winner': ['BU']},
#   '4474452478': {'Action': [['UTGf', 'LJf', 'HJf', 'BUr3', 'SBf', 'BBf']],
#                  'Board': None,
#                  'Players': [['LJ', '', 142, ('8d', '5h')],
#                              ['HJ', 'Hero', 49, ('3c', 'Ks')],
#                              ['BU', '', 96, ('7c', '7d')],
#                              ['SB', '', 149, ('6s', 'Jc')],
#                              ['BB', '', 218, ('Kc', '3s')],
#                              ['UTG', '', 38, ('5c', '9s')]],
#                  'Stakes': (0.02, 0.05),
#                  'WTSD': True,
#                  'Winner': ['BU']},
#   '4474452514': {'Action': [['UTGc1', 'LJf', 'HJf', 'BUf', 'SBf', 'BBx'],
#                             ['BBx', 'UTGb1', 'BBr3', 'UTGc2'],
#                             ['BBb6', 'UTGf']],
#                  'Board': None,
#                  'Players': [['UTG', '', 60, ('5h', '5d')],
#                              ['LJ', 'Hero', 49, ('8c', 'Kh')],
#                              ['HJ', '', 80, ('7h', 'Qc')],
#                              ['BU', '', 687, ('4c', 'Jh')],
#                              ['SB', '', 142, ('Qs', '2d')],
#                              ['BB', '', 100, ('6h', '7c')]],
#                  'Stakes': (0.02, 0.05),
#                  'WTSD': True,
#                  'Winner': [None, 'BB']},
#   '4474452548': {'Action': [['UTGf', 'LJf', 'HJf', 'BUf', 'SBf']],
#                  'Board': None,
#                  'Players': [['HJ', '', 147, ('7c', '3h')],
#                              ['BU', '', 309, ('Qh', '4d')],
#                              ['SB', '', 99, ('Jd', '3c')],
#                              ['BB', '', 142, ('5s', '2d')],
#                              ['UTG', 'Hero', 49, ('8h', '6c')],
#                              ['LJ', '', 96, ('6d', '7d')]],
#                  'Stakes': (0.02, 0.05),
#                  'WTSD': True,
#                  'Winner': ['BB', None]},
#   '4474452586': {'Action': [['UTGr3', 'LJf', 'HJf', 'BUf', 'SBf', 'BBf']],
#                  'Board': None,
#                  'Players': [['LJ', 'Hero', 49, ('4d', '6s')],
#                              ['HJ', '', 38, ('2h', '6d')],
#                              ['BU', '', 91, ('6c', 'Ad')],
#                              ['SB', '', 80, ('2d', 'Kd')],
#                              ['BB', '', 107, ('8c', '6h')],
#                              ['UTG', '', 159, ('Ts', '9s')]],
#                  'Stakes': (0.02, 0.05),
#                  'WTSD': True,
#                  'Winner': ['UTG']},
#   '4474452620': {'Action': [['UTGf', 'LJf', 'HJr3', 'BUf', 'SBf', 'BBf']],
#                  'Board': None,
#                  'Players': [['BB', 'Hero', 49, ('5s', '4s')],
#                              ['UTG', '', 113, ('3c', '4d')],
#                              ['LJ', '', 217, ('3s', '2h')],
#                              ['HJ', '', 91, ('Th', 'Jh')],
#                              ['BU', '', 38, ('9h', '7c')],
#                              ['SB', '', 131, ('8h', '5h')]],
#                  'Stakes': (0.02, 0.05),
#                  'WTSD': True,
#                  'Winner': ['HJ']},
#   '4474452701': {'Action': [['UTGf', 'LJf', 'HJf', 'BUf', 'SBr3', 'BBc2'],
#                             ['SBx', 'BBx'],
#                             ['SBb3', 'BBf']],
#                  'Board': None,
#                  'Players': [['BB', '', 99, ('Jd', 'Ks')],
#                              ['UTG', '', 121, ('7c', 'Ts')],
#                              ['LJ', '', 116, ('Kh', '4d')],
#                              ['HJ', '', 106, ('2h', '5h')],
#                              ['BU', 'Hero', 48, ('2s', '8d')],
#                              ['SB', '', 119, ('6s', 'Qs')]],
#                  'Stakes': (0.02, 0.05),
#                  'WTSD': True,
#                  'Winner': ['SB']},
#   '4474452790': {'Action': [['UTGf', 'LJf', 'HJf', 'BUr3', 'SBf', 'BBf']],
#                  'Board': None,
#                  'Players': [['UTG', '', 67, ('Qc', '4d')],
#                              ['LJ', '', 101, ('Ad', '4s')],
#                              ['HJ', 'Hero', 48, ('Jd', 'Ks')],
#                              ['BU', '', 87, ('5d', '5c')],
#                              ['SB', '', 111, ('Kh', '2d')],
#                              ['BB', '', 116, ('5h', '9c')]],
#                  'Stakes': (0.02, 0.05),
#                  'WTSD': True,
#                  'Winner': ['BU']},
#   '4474452827': {'Action': [['UTGf', 'LJf', 'HJf', 'BUf', 'SBf']],
#                  'Board': None,
#                  'Players': [['BU', '', 100, ('3h', 'As')],
#                              ['SB', '', 131, ('2d', '5s')],
#                              ['BB', '', 144, ('4c', 'Js')],
#                              ['UTG', '', 136, ('8d', 'Tc')],
#                              ['LJ', '', 142, ('4s', '2s')],
#                              ['HJ', 'Hero', 48, ('Qs', '7h')]],
#                  'Stakes': (0.02, 0.05),
#                  'WTSD': True,
#                  'Winner': ['BB']},
#   '4474452882': {'Action': [['UTGf', 'LJc1', 'HJf', 'BUf', 'SBf', 'BBx'],
#                             ['BBx', 'LJb1', 'BBf']],
#                  'Board': None,
#                  'Players': [['SB', '', 96, ('5h', '2h')],
#                              ['BB', '', 690, ('2d', 'Jh')],
#                              ['UTG', '', 67, ('5s', 'Ac')],
#                              ['LJ', '', 60, ('6d', '4d')],
#                              ['HJ', '', 121, ('8d', 'Ah')],
#                              ['BU', 'Hero', 48, ('8s', 'Qc')]],
#                  'Stakes': (0.02, 0.05),
#                  'WTSD': True,
#                  'Winner': ['LJ']},
#   '4474452915': {'Action': [['UTGf', 'LJf', 'HJf', 'BUr3', 'SBf', 'BBf']],
#                  'Board': None,
#                  'Players': [['SB', '', 159, ('7h', 'Tc')],
#                              ['BB', '', 100, ('6s', '2s')],
#                              ['UTG', '', 116, ('Jd', '5c')],
#                              ['LJ', '', 144, ('9d', 'As')],
#                              ['HJ', 'Hero', 48, ('8s', 'Qc')],
#                              ['BU', '', 319, ('Ac', 'Jc')]],
#                  'Stakes': (0.02, 0.05),
#                  'WTSD': True,
#                  'Winner': ['BU', None]},
#   '4474452959': {'Action': [['UTGf', 'LJf', 'HJr2', 'BUc2', 'SBf', 'BBf'],
#                             ['HJb2', 'BUf']],
#                  'Board': None,
#                  'Players': [['SB', '', 100, ('4h', '7c')],
#                              ['BB', 'Hero', 48, ('Tc', 'Jd')],
#                              ['UTG', '', 78, ('9d', '6h')],
#                              ['LJ', '', 159, ('Ks', '8h')],
#                              ['HJ', '', 156, ('Jc', 'Qh')],
#                              ['BU', '', 547, ('7h', '8d')]],
#                  'Stakes': (0.02, 0.05),
#                  'WTSD': True,
#                  'Winner': ['HJ']},
#   '4474453002': {'Action': [['UTGf', 'LJf', 'HJc1', 'BUf', 'SBc1', 'BBx'],
#                             ['SBx', 'BBx', 'HJx'],
#                             ['SBx', 'BBx', 'HJb3', 'SBf', 'BBf']],
#                  'Board': None,
#                  'Players': [['BB', '', 90, ('2h', '8c')],
#                              ['UTG', 'Hero', 47, ('5d', 'Qs')],
#                              ['LJ', '', 159, ('9h', '8h')],
#                              ['HJ', '', 61, ('Qc', '2c')],
#                              ['BU', '', 78, ('4d', 'Kh')],
#                              ['SB', '', 178, ('9d', 'Ac')]],
#                  'Stakes': (0.02, 0.05),
#                  'WTSD': True,
#                  'Winner': ['HJ']},
#   '4474453035': {'Action': [['UTGf', 'LJf', 'HJf', 'BUr2', 'SBf', 'BBf']],
#                  'Board': None,
#                  'Players': [['BU', '', 689, ('5h', '6h')],
#                              ['SB', '', 327, ('9h', '3c')],
#                              ['BB', '', 253, ('7d', 'Qc')],
#                              ['UTG', 'Hero', 47, ('4d', '5d')],
#                              ['LJ', '', 105, ('9d', 'Jc')],
#                              ['HJ', '', 166, ('Js', '8h')]],
#                  'Stakes': (0.02, 0.05),
#                  'WTSD': True,
#                  'Winner': ['BU']},
#   '4474453066': {'Action': [['UTGf', 'LJf', 'HJf', 'BUf', 'SBf']],
#                  'Board': None,
#                  'Players': [['BB', '', 279, ('Ad', 'Th')],
#                              ['UTG', '', 55, ('Kc', '5d')],
#                              ['LJ', '', 137, ('Jc', '4h')],
#                              ['HJ', 'Hero', 47, ('7s', '9c')],
#                              ['BU', '', 100, ('5h', 'Tc')],
#                              ['SB', '', 166, ('2c', '9h')]],
#                  'Stakes': (0.02, 0.05),
#                  'WTSD': True,
#                  'Winner': ['BB']},
#   '4474453104': {'Action': [['UTGr2',
#                              'LJf',
#                              'HJr47',
#                              'BUf',
#                              'SBf',
#                              'BBf',
#                              'UTGf']],
#                  'Board': None,
#                  'Players': [['HJ', 'Hero', 47, ('Qh', 'Jh')],
#                              ['BU', '', 320, ('3s', '8d')],
#                              ['SB', '', 100, ('3d', 'Th')],
#                              ['BB', '', 78, ('9h', '8c')],
#                              ['UTG', '', 120, ('9d', 'Qd')],
#                              ['LJ', '', 60, ('5h', '8s')]],
#                  'Stakes': (0.02, 0.05),
#                  'WTSD': True,
#                  'Winner': ['HJ', 'HJ']},
#   '4474453267': {'Action': [['UTGf', 'LJf', 'HJf', 'BUf', 'SBr3', 'BBf']],
#                  'Board': None,
#                  'Players': [['SB', '', 158, ('Tc', 'Jh')],
#                              ['BB', '', 176, ('Kh', '3c')],
#                              ['UTG', '', 116, ('Ac', '9h')],
#                              ['LJ', 'Hero', 100, ('Ah', '2h')],
#                              ['HJ', '', 144, ('9d', '4d')],
#                              ['BU', '', 64, ('8h', '7s')]],
#                  'Stakes': (0.02, 0.05),
#                  'WTSD': True,
#                  'Winner': ['SB', None]}},
#  {'4474452169': {'Action': [['UTGc1', 'LJf', 'HJf', 'BUf', 'SBf', 'BBx'],
#                             ['BBx', 'UTGb1', 'BBf']],
#                  'Board': None,
#                  'Players': [['SB', '', 99, ('4s', 'Jd')],
#                              ['BB', 'Hero', 50, ('Ac', '6h')],
#                              ['UTG', '', 53, ('Tc', 'Jc')],
#                              ['LJ', '', 63, ('8h', '3s')],
#                              ['HJ', '', 97, ('2s', 'Ks')],
#                              ['BU', '', 121, ('5s', 'Kc')]],
#                  'Stakes': (0.02, 0.05),
#                  'WTSD': True,
#                  'Winner': ['UTG']},
#   '4474452215': {'Action': [['UTGf',
#                              'LJr3',
#                              'HJr9',
#                              'BUf',
#                              'SBf',
#                              'BBf',
#                              'LJc6'],
#                             ['LJx', 'HJb6', 'LJf']],
#                  'Board': ['Ad', '8c', '5d', '', ''],
#                  'Players': [['UTG', '', 116, ('5c', '4h')],
#                              ['LJ', '', 97, ('Ks', 'Jh')],
#                              ['HJ', '', 133, ('Qh', 'Kh')],
#                              ['BU', 'Hero', 49, ('Jc', '6h')],
#                              ['SB', '', 63, ('Js', '9s')],
#                              ['BB', '', 100, ('Ac', '4s')]],
#                  'Stakes': (0.02, 0.05),
#                  'WTSD': True,
#                  'Winner': ['HJ', None]},
#   '4474452274': {'Action': [['UTGf', 'LJc1', 'HJf', 'BUf', 'SBc1', 'BBx'],
#                             ['SBx', 'BBx', 'LJx'],
#                             ['SBb2', 'BBf', 'LJc2'],
#                             ['SBx', 'LJb7', 'SBc7']],
#                  'Board': None,
#                  'Players': [['UTG', '', 151, ('4d', '2h')],
#                              ['LJ', '', 53, ('Js', '8h')],
#                              ['HJ', '', 230, ('5d', '4s')],
#                              ['BU', 'Hero', 49, ('Kd', '6s')],
#                              ['SB', '', 140, ('Kc', 'Ts')],
#                              ['BB', '', 61, ('3d', '3s')]],
#                  'Stakes': (0.02, 0.05),
#                  'WTSD': True,
#                  'Winner': ['LJ']},
#   '4474452332': {'Action': [['UTGf', 'LJr2', 'HJf', 'BUf', 'SBf', 'BBf']],
#                  'Board': None,
#                  'Players': [['LJ', '', 111, ('Th', 'Jh')],
#                              ['HJ', 'Hero', 49, ('Td', '8s')],
#                              ['BU', '', 177, ('Js', '7h')],
#                              ['SB', '', 151, ('7d', '4s')],
#                              ['BB', '', 48, ('As', 'Jd')],
#                              ['UTG', '', 54, ('9d', '3h')]],
#                  'Stakes': (0.02, 0.05),
#                  'WTSD': True,
#                  'Winner': ['LJ']},
#   '4474452401': {'Action': [['UTGf', 'LJf', 'HJf', 'BUf', 'SBc1', 'BBx'],
#                             ['SBx', 'BBx'],
#                             ['SBx', 'BBx'],
#                             ['SBx', 'BBx']],
#                  'Board': None,
#                  'Players': [['BU', 'Hero', 49, ('5c', '2s')],
#                              ['SB', '', 157, ('Th', 'Qd')],
#                              ['BB', '', 215, ('8s', 'Ac')],
#                              ['UTG', '', 180, ('6d', '3s')],
#                              ['LJ', '', 119, ('Td', '6h')],
#                              ['HJ', '', 132, ('Qs', '5d')]],
#                  'Stakes': (0.02, 0.05),
#                  'WTSD': True,
#                  'Winner': ['BB']},
#   '4474452438': {'Action': [['UTGr3', 'LJf', 'HJf', 'BUf', 'SBf', 'BBf']],
#                  'Board': None,
#                  'Players': [['BU', 'Hero', 49, ('Kd', '2h')],
#                              ['SB', '', 103, ('2s', 'Qd')],
#                              ['BB', '', 132, ('7s', '2d')],
#                              ['UTG', '', 259, ('6d', '6s')],
#                              ['LJ', '', 92, ('Ac', '5h')],
#                              ['HJ', '', 147, ('Td', '9c')]],
#                  'Stakes': (0.02, 0.05),
#                  'WTSD': True,
#                  'Winner': ['UTG', None]},
#   '4474452488': {'Action': [['UTGr3', 'LJf', 'HJf', 'BUc3', 'SBf', 'BBf'],
#                             ['UTGb5', 'BUc5'],
#                             ['UTGb17', 'BUf']],
#                  'Board': None,
#                  'Players': [['SB', 'Hero', 49, ('2d', 'Qc')],
#                              ['BB', '', 92, ('5h', 'Jh')],
#                              ['UTG', '', 177, ('Js', 'Kd')],
#                              ['LJ', '', 114, ('Jc', '8h')],
#                              ['HJ', '', 112, ('9d', '4d')],
#                              ['BU', '', 103, ('Qd', '6d')]],
#                  'Stakes': (0.02, 0.05),
#                  'WTSD': True,
#                  'Winner': ['UTG']},
#   '4474452525': {'Action': [['UTGc1',
#                              'LJf',
#                              'HJf',
#                              'BUc1',
#                              'SBr6',
#                              'BBf',
#                              'UTGc5',
#                              'BUf'],
#                             ['SBb5', 'UTGr118', 'SBf']],
#                  'Board': None,
#                  'Players': [['LJ', '', 117, ('2s', 'Kc')],
#                              ['HJ', '', 113, ('8c', '7d')],
#                              ['BU', '', 159, ('7c', 'Qc')],
#                              ['SB', '', 104, ('Kh', '9h')],
#                              ['BB', 'Hero', 49, ('4d', '4c')],
#                              ['UTG', '', 124, ('Ah', 'Jh')]],
#                  'Stakes': (0.02, 0.05),
#                  'WTSD': True,
#                  'Winner': ['UTG']},
#   '4474452578': {'Action': [['UTGf', 'LJr2', 'HJf', 'BUf', 'SBf', 'BBc1'],
#                             ['BBx', 'LJb5', 'BBc5'],
#                             ['BBx', 'LJb11', 'BBf']],
#                  'Board': ['Kc', 'Js', 'Qh', '2h', ''],
#                  'Players': [['SB', '', 100, ('Qc', '2d')],
#                              ['BB', '', 174, ('3d', 'Ac')],
#                              ['UTG', 'Hero', 48, ('6d', 'Ah')],
#                              ['LJ', '', 149, ('As', 'Ks')],
#                              ['HJ', '', 230, ('3c', 'Ts')],
#                              ['BU', '', 121, ('7c', '9h')]],
#                  'Stakes': (0.02, 0.05),
#                  'WTSD': True,
#                  'Winner': ['LJ', None]},
#   '4474452617': {'Action': [['UTGf', 'LJf', 'HJf', 'BUr3', 'SBc3', 'BBf'],
#                             ['SBx', 'BUx'],
#                             ['SBx', 'BUx'],
#                             ['SBx', 'BUx']],
#                  'Board': ['7h', '3d', 'Tc', 'Th', '3s'],
#                  'Players': [['HJ', 'Hero', 48, ('Jh', '2c')],
#                              ['BU', '', 99, ('Jd', 'Qs')],
#                              ['SB', '', 687, ('9d', 'Ad')],
#                              ['BB', '', 117, ('8c', 'Kd')],
#                              ['UTG', '', 112, ('9c', 'Kh')],
#                              ['LJ', '', 309, ('8h', 'Ks')]],
#                  'Stakes': (0.02, 0.05),
#                  'WTSD': True,
#                  'Winner': ['SB', None]},
#   '4474452688': {'Action': [['UTGf', 'LJf', 'HJf', 'BUf', 'SBr3', 'BBc2'],
#                             ['SBb3', 'BBf']],
#                  'Board': None,
#                  'Players': [['SB', '', 113, ('9c', '9h')],
#                              ['BB', '', 63, ('3d', '6s')],
#                              ['UTG', '', 130, ('5s', '6h')],
#                              ['LJ', '', 309, ('7h', 'Qh')],
#                              ['HJ', '', 93, ('3h', '5d')],
#                              ['BU', 'Hero', 48, ('7s', 'Ts')]],
#                  'Stakes': (0.02, 0.05),
#                  'WTSD': True,
#                  'Winner': ['SB']},
#   '4474452789': {'Action': [['UTGf', 'LJf', 'HJf', 'BUf', 'SBc1', 'BBx'],
#                             ['SBx', 'BBx'],
#                             ['SBb8', 'BBf']],
#                  'Board': None,
#                  'Players': [['SB', '', 216, ('9s', 'Ts')],
#                              ['BB', '', 117, ('9h', 'Qd')],
#                              ['UTG', '', 116, ('Qh', '5s')],
#                              ['LJ', 'Hero', 48, ('As', '2d')],
#                              ['HJ', '', 136, ('7d', 'Js')],
#                              ['BU', '', 92, ('9c', '8d')]],
#                  'Stakes': (0.02, 0.05),
#                  'WTSD': True,
#                  'Winner': ['SB']},
#   '4474452816': {'Action': [['UTGf', 'LJf', 'HJf', 'BUf', 'SBr3', 'BBc2'],
#                             ['SBb3', 'BBf']],
#                  'Board': ['7d', '4s', 'Kd', '', ''],
#                  'Players': [['LJ', '', 78, ('6h', 'Ts')],
#                              ['HJ', '', 121, ('9s', 'Tc')],
#                              ['BU', 'Hero', 48, ('5c', '9h')],
#                              ['SB', '', 116, ('8c', '9c')],
#                              ['BB', '', 101, ('Jh', '9d')],
#                              ['UTG', '', 67, ('5s', '2h')]],
#                  'Stakes': (0.02, 0.05),
#                  'WTSD': True,
#                  'Winner': ['SB', None]},
#   '4474452848': {'Action': [['UTGf',
#                              'LJf',
#                              'HJr3',
#                              'BUf',
#                              'SBr12',
#                              'BBf',
#                              'HJf']],
#                  'Board': None,
#                  'Players': [['BU', '', 200, ('3h', '5c')],
#                              ['SB', '', 93, ('Jc', 'Jh')],
#                              ['BB', 'Hero', 48, ('7d', '5d')],
#                              ['UTG', '', 121, ('6h', '8h')],
#                              ['LJ', '', 78, ('Tc', '6c')],
#                              ['HJ', '', 95, ('9d', 'Qh')]],
#                  'Stakes': (0.02, 0.05),
#                  'WTSD': True,
#                  'Winner': ['SB', None]},
#   '4474452905': {'Action': [['UTGf', 'LJf', 'HJf', 'BUf', 'SBf']],
#                  'Board': None,
#                  'Players': [['LJ', '', 100, ('Kh', '5d')],
#                              ['HJ', '', 111, ('3h', '2s')],
#                              ['BU', 'Hero', 47, ('As', '7s')],
#                              ['SB', '', 78, ('Td', '8h')],
#                              ['BB', '', 123, ('Ts', '9d')],
#                              ['UTG', '', 547, ('9s', '5s')]],
#                  'Stakes': (0.02, 0.05),
#                  'WTSD': True,
#                  'Winner': ['BB']},
#   '4474452962': {'Action': [['UTGf', 'LJf', 'HJf', 'BUr47', 'SBf', 'BBf']],
#                  'Board': None,
#                  'Players': [['BU', 'Hero', 47, ('8d', '8c')],
#                              ['SB', '', 207, ('3d', '2s')],
#                              ['BB', '', 56, ('Qc', '9s')],
#                              ['UTG', '', 121, ('As', '4d')],
#                              ['LJ', '', 116, ('3h', 'Ts')],
#                              ['HJ', '', 115, ('6h', 'Th')]],
#                  'Stakes': (0.02, 0.05),
#                  'WTSD': True,
#                  'Winner': ['BU', None]},
#   '4474453103': {'Action': [['UTGf', 'LJf', 'HJf', 'BUf', 'SBf']],
#                  'Board': None,
#                  'Players': [['LJ', '', 104, ('4c', 'Jh')],
#                              ['HJ', 'Hero', 99, ('6d', 'Jc')],
#                              ['BU', '', 64, ('Td', '8c')],
#                              ['SB', '', 119, ('4h', '7d')],
#                              ['BB', '', 53, ('9d', '6h')],
#                              ['UTG', '', 154, ('Qs', '9s')]],
#                  'Stakes': (0.02, 0.05),
#                  'WTSD': True,
#                  'Winner': ['BB']},
#   '4474453131': {'Action': [['UTGf', 'LJf', 'HJf', 'BUf', 'SBf']],
#                  'Board': None,
#                  'Players': [['BB', '', 100, ('Th', '8s')],
#                              ['UTG', '', 64, ('Jd', '5h')],
#                              ['LJ', 'Hero', 99, ('Qh', '8c')],
#                              ['HJ', '', 545, ('3c', '4c')],
#                              ['BU', '', 97, ('2d', '6s')],
#                              ['SB', '', 118, ('Td', '3d')]],
#                  'Stakes': (0.02, 0.05),
#                  'WTSD': True,
#                  'Winner': ['BB']}},
#  {'4474453486': {'Action': [['UTGf', 'LJf', 'HJf', 'BUf', 'SBf']],
#                  'Board': None,
#                  'Players': [['LJ', '', 98, ('2h', 'Qc')],
#                              ['HJ', '', 155, ('Th', '2c')],
#                              ['BU', '', 152, ('Jd', '7h')],
#                              ['SB', '', 256, ('4h', '2s')],
#                              ['BB', 'Hero', 51, ('8d', '4c')],
#                              ['UTG', '', 100, ('6h', '8s')]],
#                  'Stakes': (0.02, 0.05),
#                  'WTSD': True,
#                  'Winner': ['BB']},
#   '4474453544': {'Action': [['UTGr3', 'LJf', 'HJf', 'BUf', 'SBf', 'BBf']],
#                  'Board': None,
#                  'Players': [['HJ', 'Hero', 51, ('Jd', '9d')],
#                              ['BU', '', 281, ('3c', '2c')],
#                              ['SB', '', 82, ('8c', 'Td')],
#                              ['BB', '', 180, ('2d', '4s')],
#                              ['UTG', '', 98, ('7d', 'Kd')],
#                              ['LJ', '', 71, ('6d', '5d')]],
#                  'Stakes': (0.02, 0.05),
#                  'WTSD': True,
#                  'Winner': ['UTG']},
#   '4474453574': {'Action': [['UTGf',
#                              'LJf',
#                              'HJr3',
#                              'BUf',
#                              'SBf',
#                              'BBr8',
#                              'HJc6'],
#                             ['BBx', 'HJx'],
#                             ['BBb9', 'HJc9'],
#                             ['BBb17', 'HJf']],
#                  'Board': ['8c', 'Ks', '5d', 'Kc', 'Js'],
#                  'Players': [['LJ', '', 96, ('8h', '4s')],
#                              ['HJ', '', 151, ('Qc', 'Ts')],
#                              ['BU', '', 107, ('6s', '2s')],
#                              ['SB', 'Hero', 51, ('2d', 'Jh')],
#                              ['BB', '', 688, ('Qd', 'Qh')],
#                              ['UTG', '', 112, ('Td', '6h')]],
#                  'Stakes': (0.02, 0.05),
#                  'WTSD': True,
#                  'Winner': ['BB', None]},
#   '4474453609': {'Action': [['UTGf', 'LJf', 'HJf', 'BUf', 'SBr3', 'BBc2'],
#                             ['SBb3', 'BBc3'],
#                             ['SBb6', 'BBc6'],
#                             ['SBx', 'BBb11', 'SBc11']],
#                  'Board': None,
#                  'Players': [['SB', '', 87, ('5c', 'As')],
#                              ['BB', '', 53, ('7s', '5d')],
#                              ['UTG', 'Hero', 51, ('9h', 'Ad')],
#                              ['LJ', '', 107, ('3c', '7h')],
#                              ['HJ', '', 175, ('5h', 'Kh')],
#                              ['BU', '', 96, ('Ts', '6c')]],
#                  'Stakes': (0.02, 0.05),
#                  'WTSD': True,
#                  'Winner': ['BB']},
#   '4474453641': {'Action': [['UTGr3',
#                              'LJr9',
#                              'HJf',
#                              'BUf',
#                              'SBf',
#                              'BBf',
#                              'UTGc5'],
#                             ['UTGx', 'LJb4', 'UTGc4'],
#                             ['UTGx', 'LJb17', 'UTGf']],
#                  'Board': ['7h', '4h', '2h', '4c', ''],
#                  'Players': [['UTG', '', 131, ('Qh', 'Ac')],
#                              ['LJ', '', 204, ('Kc', 'Kh')],
#                              ['HJ', '', 144, ('Tc', '4d')],
#                              ['BU', '', 98, ('Ad', '5h')],
#                              ['SB', 'Hero', 51, ('6s', '9h')],
#                              ['BB', '', 100, ('3c', '7d')]],
#                  'Stakes': (0.02, 0.05),
#                  'WTSD': True,
#                  'Winner': ['LJ', None]},
#   '4474453690': {'Action': [['UTGf', 'LJf', 'HJf', 'BUc1', 'SBc1', 'BBx'],
#                             ['SBb2', 'BBf', 'BUc2'],
#                             ['SBb5', 'BUc5'],
#                             ['SBx', 'BUx']],
#                  'Board': None,
#                  'Players': [['HJ', '', 75, ('Td', '3s')],
#                              ['BU', '', 150, ('2c', 'Qh')],
#                              ['SB', '', 104, ('9s', 'Qs')],
#                              ['BB', 'Hero', 51, ('6s', '7h')],
#                              ['UTG', '', 543, ('Th', 'Ks')],
#                              ['LJ', '', 100, ('5c', '4h')]],
#                  'Stakes': (0.02, 0.05),
#                  'WTSD': True,
#                  'Winner': ['SB']},
#   '4474453723': {'Action': [['UTGf',
#                              'LJr3',
#                              'HJf',
#                              'BUr50',
#                              'SBf',
#                              'BBf',
#                              'LJf']],
#                  'Board': None,
#                  'Players': [['UTG', '', 99, ('7h', 'Jd')],
#                              ['LJ', '', 76, ('8d', '9d')],
#                              ['HJ', '', 100, ('5d', '8c')],
#                              ['BU', 'Hero', 50, ('Ac', 'Qh')],
#                              ['SB', '', 150, ('Tc', '8s')],
#                              ['BB', '', 173, ('Td', '3h')]],
#                  'Stakes': (0.02, 0.05),
#                  'WTSD': True,
#                  'Winner': ['BU', 'BU']},
#   '4474453891': {'Action': [['UTGf', 'LJf', 'HJf', 'BUf', 'SBf']],
#                  'Board': None,
#                  'Players': [['SB', '', 117, ('2c', '9s')],
#                              ['BB', '', 105, ('Qs', '5h')],
#                              ['UTG', '', 53, ('7h', 'Js')],
#                              ['LJ', 'Hero', 100, ('Kd', '4d')],
#                              ['HJ', '', 236, ('8h', '6s')],
#                              ['BU', '', 180, ('9h', '5c')]],
#                  'Stakes': (0.02, 0.05),
#                  'WTSD': True,
#                  'Winner': ['BB']}},
#  {'4474453500': {'Action': [['UTGf', 'LJf', 'HJf', 'BUr3', 'SBc3', 'BBf'],
#                             ['SBx', 'BUb3', 'SBc3'],
#                             ['SBx', 'BUx'],
#                             ['SBb10', 'BUf']],
#                  'Board': None,
#                  'Players': [['BB', 'Hero', 51, ('Ac', '4s')],
#                              ['UTG', '', 180, ('7s', '5c')],
#                              ['LJ', '', 101, ('Qh', '2c')],
#                              ['HJ', '', 281, ('4d', '6s')],
#                              ['BU', '', 112, ('Ah', '6h')],
#                              ['SB', '', 115, ('7d', 'Kd')]],
#                  'Stakes': (0.02, 0.05),
#                  'WTSD': True,
#                  'Winner': ['SB']},
#   '4474453552': {'Action': [['UTGf', 'LJf', 'HJf', 'BUr3', 'SBf', 'BBf']],
#                  'Board': None,
#                  'Players': [['HJ', 'Hero', 50, ('3c', 'Qd')],
#                              ['BU', '', 117, ('Th', '9s')],
#                              ['SB', '', 145, ('6h', '8c')],
#                              ['BB', '', 205, ('9d', '5c')],
#                              ['UTG', '', 53, ('Js', '2c')],
#                              ['LJ', '', 87, ('3d', '8h')]],
#                  'Stakes': (0.02, 0.05),
#                  'WTSD': True,
#                  'Winner': ['BU', None]},
#   '4474453592': {'Action': [['UTGf', 'LJf', 'HJf', 'BUf', 'SBf']],
#                  'Board': None,
#                  'Players': [['HJ', '', 71, ('6d', 'Ah')],
#                              ['BU', '', 131, ('Td', '6h')],
#                              ['SB', 'Hero', 50, ('Qh', '9c')],
#                              ['BB', '', 100, ('9d', '6c')],
#                              ['UTG', '', 98, ('9s', '7c')],
#                              ['LJ', '', 144, ('4s', '3h')]],
#                  'Stakes': (0.02, 0.05),
#                  'WTSD': True,
#                  'Winner': ['BB']},
#   '4474453628': {'Action': [['UTGf', 'LJf', 'HJr3', 'BUf', 'SBf', 'BBf']],
#                  'Board': None,
#                  'Players': [['UTG', '', 255, ('Jc', 'Ts')],
#                              ['LJ', '', 113, ('8s', 'Th')],
#                              ['HJ', '', 81, ('Jd', 'Qh')],
#                              ['BU', '', 179, ('5s', '2c')],
#                              ['SB', 'Hero', 50, ('6s', '2d')],
#                              ['BB', '', 112, ('Qd', '2s')]],
#                  'Stakes': (0.02, 0.05),
#                  'WTSD': True,
#                  'Winner': ['HJ']},
#   '4474453673': {'Action': [['UTGf', 'LJf', 'HJf', 'BUf', 'SBf']],
#                  'Board': None,
#                  'Players': [['SB', 'Hero', 49, ('Td', '2c')],
#                              ['BB', '', 255, ('Jd', '3h')],
#                              ['UTG', '', 217, ('4s', '9c')],
#                              ['LJ', '', 138, ('Kh', '2h')],
#                              ['HJ', '', 100, ('3c', '8c')],
#                              ['BU', '', 179, ('4h', 'Kc')]],
#                  'Stakes': (0.02, 0.05),
#                  'WTSD': True,
#                  'Winner': ['BB', None]},
#   '4474453701': {'Action': [['UTGf', 'LJf', 'HJr3', 'BUf', 'SBf', 'BBf']],
#                  'Board': None,
#                  'Players': [['BU', '', 115, ('Jc', '5d')],
#                              ['SB', '', 61, ('3d', 'Kc')],
#                              ['BB', 'Hero', 49, ('Jd', '8d')],
#                              ['UTG', '', 137, ('As', '2d')],
#                              ['LJ', '', 217, ('6s', '2s')],
#                              ['HJ', '', 179, ('7s', '7d')]],
#                  'Stakes': (0.02, 0.05),
#                  'WTSD': True,
#                  'Winner': ['HJ', None]},
#   '4474453730': {'Action': [['UTGf',
#                              'LJf',
#                              'HJr3',
#                              'BUc3',
#                              'SBr47',
#                              'BBf',
#                              'HJf',
#                              'BUf']],
#                  'Board': None,
#                  'Players': [['BU', '', 220, ('8d', '7d')],
#                              ['SB', 'Hero', 48, ('Ah', 'Th')],
#                              ['BB', '', 122, ('4h', '5s')],
#                              ['UTG', '', 217, ('9h', 'Jh')],
#                              ['LJ', '', 543, ('4d', '2s')],
#                              ['HJ', '', 320, ('Ts', 'Jd')]],
#                  'Stakes': (0.02, 0.05),
#                  'WTSD': True,
#                  'Winner': ['SB']},
#   '4474453926': {'Action': [['UTGc1',
#                              'LJf',
#                              'HJr55',
#                              'BUf',
#                              'SBf',
#                              'BBf',
#                              'UTGf']],
#                  'Board': None,
#                  'Players': [['SB', '', 322, ('Js', 'Kd')],
#                              ['BB', '', 100, ('Jh', '3s')],
#                              ['UTG', '', 113, ('2d', 'Qd')],
#                              ['LJ', '', 121, ('9h', '7s')],
#                              ['HJ', 'Hero', 55, ('Kc', 'Ad')],
#                              ['BU', '', 255, ('Tc', 'Qh')]],
#                  'Stakes': (0.02, 0.05),
#                  'WTSD': True,
#                  'Winner': ['HJ', 'HJ']},
#   '4474454111': {'Action': [['UTGf', 'LJr3', 'HJc3', 'BUf', 'SBf', 'BBf'],
#                             ['LJx', 'HJx'],
#                             ['LJb4', 'HJc4'],
#                             ['LJb7', 'HJc7']],
#                  'Board': None,
#                  'Players': [['LJ', '', 153, ('Ah', 'Jh')],
#                              ['HJ', '', 74, ('Ts', '7s')],
#                              ['BU', '', 99, ('5h', '8s')],
#                              ['SB', 'Hero', 100, ('5d', 'Ks')],
#                              ['BB', '', 89, ('4c', '3h')],
#                              ['UTG', '', 105, ('3s', '2c')]],
#                  'Stakes': (0.02, 0.05),
#                  'WTSD': True,
#                  'Winner': ['LJ']}},
#  {'4474454112': {'Action': [['UTGf', 'LJf', 'HJf', 'BUf', 'SBr3', 'BBf']],
#                  'Board': None,
#                  'Players': [['SB', '', 95, ('Jh', 'Ts')],
#                              ['BB', 'Hero', 51, ('4s', 'Kc')],
#                              ['UTG', '', 224, ('7s', '2c')],
#                              ['LJ', '', 133, ('8c', 'Qs')],
#                              ['HJ', '', 117, ('Qh', '9c')],
#                              ['BU', '', 542, ('2d', '7d')]],
#                  'Stakes': (0.02, 0.05),
#                  'WTSD': True,
#                  'Winner': [None, 'SB']},
#   '4474454151': {'Action': [['UTGf', 'LJf', 'HJf', 'BUf', 'SBc1', 'BBx'],
#                             ['SBb1', 'BBf']],
#                  'Board': None,
#                  'Players': [['BB', '', 133, ('3s', 'Jc')],
#                              ['UTG', '', 224, ('9d', 'Qc')],
#                              ['LJ', 'Hero', 50, ('8h', 'Ad')],
#                              ['HJ', '', 217, ('7s', 'Ks')],
#                              ['BU', '', 105, ('2d', '3d')],
#                              ['SB', '', 21, ('Qd', 'Kh')]],
#                  'Stakes': (0.02, 0.05),
#                  'WTSD': True,
#                  'Winner': ['SB']},
#   '4474454208': {'Action': [['UTGf', 'LJr3', 'HJf', 'BUf', 'SBf', 'BBf']],
#                  'Board': None,
#                  'Players': [['BB', '', 53, ('Qs', '2h')],
#                              ['UTG', '', 99, ('6h', '8s')],
#                              ['LJ', '', 136, ('Jc', 'Qd')],
#                              ['HJ', '', 241, ('Td', '8c')],
#                              ['BU', '', 217, ('Ks', '4c')],
#                              ['SB', 'Hero', 50, ('6c', '7d')]],
# ...
#                              ['UTG', '', 108, ('5c', '6h')],
#                              ['LJ', '', 109, ('Th', '5d')],
#                              ['HJ', 'Hero', 47, ('Js', '9s')],
#                              ['BU', '', 235, ('Td', 'Ac')]],
#                  'Stakes': (0.02, 0.05),
#                  'WTSD': True,
#                  'Winner': ['BU']},
#   '4474515802': {'Action': [['UTGf', 'LJf', 'HJc1', 'BUf', 'SBf', 'BBx'],
#                             ['BBx', 'HJx'],
#                             ['BBx', 'HJb2', 'BBf']],
#                  'Board': ['9c', '2c', '6c', 'Kc', ''],
#                  'Players': [['LJ', '', 101, ('9d', '4h')],
#                              ['HJ', '', 84, ('Jh', '3h')],
#                              ['BU', '', 164, ('6s', 'Tc')],
#                              ['SB', 'Hero', 47, ('8h', '3c')],
#                              ['BB', '', 571, ('Th', '6d')],
#                              ['UTG', '', 108, ('2h', '3d')]],
#                  'Stakes': (0.02, 0.05),
#                  'WTSD': True,
#                  'Winner': ['HJ', None]},
#   '4474515838': {'Action': [['UTGf',
#                              'LJr4',
#                              'HJf',
#                              'BUf',
#                              'SBr46',
#                              'BBf',
#                              'LJc43']],
#                  'Board': None,
#                  'Players': [['HJ', '', 83, ('8c', '3h')],
#                              ['BU', '', 138, ('4s', '2s')],
#                              ['SB', 'Hero', 47, ('Ad', 'Th')],
#                              ['BB', '', 101, ('Ts', '8d')],
#                              ['UTG', '', 108, ('2c', 'As')],
#                              ['LJ', '', 50, ('Js', 'Qs')]],
#                  'Stakes': (0.02, 0.05),
#                  'WTSD': True,
#                  'Winner': ['LJ']},
#   '4474516036': {'Action': [['UTGf', 'LJf', 'HJf', 'BUf', 'SBc1', 'BBx'],
#                             ['SBx', 'BBx'],
#                             ['SBb2', 'BBf']],
#                  'Board': ['3c', '5c', 'Jh', '8c', ''],
#                  'Players': [['BU', '', 105, ('3h', '7c')],
#                              ['SB', '', 84, ('5d', 'Td')],
#                              ['BB', '', 100, ('4s', 'Ah')],
#                              ['UTG', '', 149, ('Jd', '2s')],
#                              ['LJ', '', 114, ('6h', '5s')],
#                              ['HJ', 'Hero', 51, ('2h', 'Ad')]],
#                  'Stakes': (0.02, 0.05),
#                  'WTSD': True,
#                  'Winner': ['SB', None]},
#   '4474516108': {'Action': [['UTGf', 'LJf', 'HJf', 'BUf', 'SBr3', 'BBf']],
#                  'Board': None,
#                  'Players': [['BU', '', 44, ('2d', '4s')],
#                              ['SB', '', 99, ('Kh', '5h')],
#                              ['BB', 'Hero', 51, ('9h', '8d')],
#                              ['UTG', '', 237, ('4d', 'Kd')],
#                              ['LJ', '', 149, ('9c', '3d')],
#                              ['HJ', '', 53, ('7c', '9s')]],
#                  'Stakes': (0.02, 0.05),
#                  'WTSD': True,
#                  'Winner': ['SB']},
#   '4474516138': {'Action': [['UTGf', 'LJr3', 'HJc3', 'BUf', 'SBc3', 'BBc2'],
#                             ['SBx', 'BBx', 'LJb3', 'HJc3', 'SBf', 'BBc3'],
#                             ['BBx', 'LJx', 'HJx'],
#                             ['BBx', 'LJb21', 'HJf', 'BBr70', 'LJc49']],
#                  'Board': None,
#                  'Players': [['BB', '', 76, ('6h', '5d')],
#                              ['UTG', 'Hero', 50, ('3d', '9h')],
#                              ['LJ', '', 237, ('Qd', 'Ac')],
#                              ['HJ', '', 169, ('Td', '5h')],
#                              ['BU', '', 44, ('Ts', '2h')],
#                              ['SB', '', 149, ('9c', 'Ah')]],
#                  'Stakes': (0.02, 0.05),
#                  'WTSD': True,
#                  'Winner': ['BB']},
#   '4474516175': {'Action': [['UTGc1',
#                              'LJf',
#                              'HJr4',
#                              'BUf',
#                              'SBr50',
#                              'BBf',
#                              'UTGf',
#                              'HJf']],
#                  'Board': None,
#                  'Players': [['SB', 'Hero', 50, ('As', 'Kd')],
#                              ['BB', '', 44, ('5h', '2s')],
#                              ['UTG', '', 50, ('7s', 'Ks')],
#                              ['LJ', '', 105, ('7h', 'Qd')],
#                              ['HJ', '', 205, ('6s', '6c')],
#                              ['BU', '', 82, ('4s', 'Js')]],
#                  'Stakes': (0.02, 0.05),
#                  'WTSD': True,
#                  'Winner': [None, 'SB']},
#   '4474516356': {'Action': [['UTGf', 'LJf', 'HJf', 'BUf', 'SBf']],
#                  'Board': None,
#                  'Players': [['SB', 'Hero', 56, ('6d', 'Qh')],
#                              ['BB', '', 589, ('3s', 'Js')],
#                              ['UTG', '', 224, ('4d', '9h')],
#                              ['LJ', '', 49, ('Th', '6h')],
#                              ['HJ', '', 93, ('8s', 'Qc')],
#                              ['BU', '', 148, ('7d', 'Jc')]],
#                  'Stakes': (0.02, 0.05),
#                  'WTSD': True,
#                  'Winner': [None, 'BB']},
#   '4474516434': {'Action': [['UTGf',
#                              'LJf',
#                              'HJr3',
#                              'BUf',
#                              'SBr55',
#                              'BBf',
#                              'HJf']],
#                  'Board': None,
#                  'Players': [['BU', '', 100, ('Jh', '2d')],
#                              ['SB', 'Hero', 56, ('Ks', 'Js')],
#                              ['BB', '', 114, ('2h', 'Ts')],
#                              ['UTG', '', 113, ('9c', 'Th')],
#                              ['LJ', '', 100, ('2s', 'Td')],
#                              ['HJ', '', 589, ('6c', '5c')]],
#                  'Stakes': (0.02, 0.05),
#                  'WTSD': True,
#                  'Winner': ['SB', None]},
#   '4474516531': {'Action': [['UTGf', 'LJf', 'HJf', 'BUf', 'SBf']],
#                  'Board': None,
#                  'Players': [['SB', '', 170, ('Qd', '7h')],
#                              ['BB', '', 146, ('5h', '6s')],
#                              ['UTG', '', 48, ('Js', '7d')],
#                              ['LJ', 'Hero', 60, ('6c', 'Tc')],
#                              ['HJ', '', 99, ('Td', '3s')],
#                              ['BU', '', 169, ('Jh', '7c')]],
#                  'Stakes': (0.02, 0.05),
#                  'WTSD': True,
#                  'Winner': ['BB']},
#   '4474516573': {'Action': [['UTGf', 'LJf', 'HJf', 'BUf', 'SBr3', 'BBc2'],
#                             ['SBb2', 'BBf']],
#                  'Board': ['9d', '5c', 'Kc', '', ''],
#                  'Players': [['SB', '', 85, ('Jd', 'Js')],
#                              ['BB', '', 94, ('6c', '4h')],
#                              ['UTG', '', 170, ('7s', '4c')],
#                              ['LJ', '', 169, ('5d', 'Ts')],
#                              ['HJ', 'Hero', 60, ('Ks', '9h')],
#                              ['BU', '', 149, ('5h', '7h')]],
#                  'Stakes': (0.02, 0.05),
#                  'WTSD': True,
#                  'Winner': ['SB', None]},
#   '4474516593': {'Action': [['UTGf', 'LJc1', 'HJf', 'BUf', 'SBf', 'BBx'],
#                             ['BBx', 'LJb2', 'BBf']],
#                  'Board': None,
#                  'Players': [['LJ', '', 163, ('Qd', '9d')],
#                              ['HJ', '', 97, ('4c', '7h')],
#                              ['BU', '', 586, ('5c', '2c')],
#                              ['SB', '', 28, ('7c', '3h')],
#                              ['BB', 'Hero', 60, ('5d', 'Kc')],
#                              ['UTG', '', 170, ('4s', '2s')]],
#                  'Stakes': (0.02, 0.05),
#                  'WTSD': True,
#                  'Winner': ['LJ']},
#   '4474516617': {'Action': [['UTGr2', 'LJf', 'HJf', 'BUf', 'SBf', 'BBf']],
#                  'Board': None,
#                  'Players': [['BU', '', 190, ('8c', 'Ad')],
#                              ['SB', '', 101, ('Ks', '5c')],
#                              ['BB', '', 169, ('3h', '8d')],
#                              ['UTG', '', 146, ('Ah', 'Qh')],
#                              ['LJ', 'Hero', 59, ('5h', '3c')],
#                              ['HJ', '', 586, ('9s', '6s')]],
#                  'Stakes': (0.02, 0.05),
#                  'WTSD': True,
#                  'Winner': ['UTG', None]},
#   '4474516646': {'Action': [['UTGf', 'LJf', 'HJf', 'BUr2', 'SBf', 'BBf']],
#                  'Board': None,
#                  'Players': [['UTG', 'Hero', 59, ('Qh', '8c')],
#                              ['LJ', '', 161, ('5s', 'Kd')],
#                              ['HJ', '', 149, ('5h', 'Tc')],
#                              ['BU', '', 48, ('7d', 'Ks')],
#                              ['SB', '', 99, ('2h', '6h')],
#                              ['BB', '', 586, ('4d', 'Jh')]],
#                  'Stakes': (0.02, 0.05),
#                  'WTSD': True,
#                  'Winner': ['BU', None]},
#   '4474516678': {'Action': [['UTGf', 'LJf', 'HJf', 'BUf', 'SBf']],
#                  'Board': None,
#                  'Players': [['HJ', '', 68, ('3d', '5h')],
#                              ['BU', '', 128, ('Qc', '2h')],
#                              ['SB', '', 168, ('7h', '3c')],
#                              ['BB', '', 97, ('9d', 'Js')],
#                              ['UTG', '', 79, ('Kd', '8s')],
#                              ['LJ', 'Hero', 59, ('Qd', 'Th')]],
#                  'Stakes': (0.02, 0.05),
#                  'WTSD': True,
#                  'Winner': ['BB']}},
#  {'4474516780': {'Action': [['UTGf',
#                              'LJc1',
#                              'HJf',
#                              'BUr3',
#                              'SBf',
#                              'BBf',
#                              'LJc2'],
#                             ['LJx', 'BUb3', 'LJf']],
#                  'Board': ['Qs', '2h', 'Ts', '', ''],
#                  'Players': [['BU', '', 97, ('8c', '9s')],
#                              ['SB', '', 207, ('2d', '4s')],
#                              ['BB', 'Hero', 50, ('8s', 'Tc')],
#                              ['UTG', '', 27, ('9h', '7h')],
#                              ['LJ', '', 164, ('5c', '7c')],
#                              ['HJ', '', 154, ('3d', 'Ks')]],
#                  'Stakes': (0.02, 0.05),
#                  'WTSD': True,
#                  'Winner': ['BU', None]},
#   '4474516809': {'Action': [['UTGf', 'LJf', 'HJr12', 'BUf', 'SBf', 'BBf']],
#                  'Board': None,
#                  'Players': [['UTG', '', 168, ('Qs', '6h')],
#                              ['LJ', '', 537, ('8h', '9d')],
#                              ['HJ', '', 12, ('Tc', 'Td')],
#                              ['BU', 'Hero', 49, ('5c', 'Kd')],
#                              ['SB', '', 585, ('9h', '5h')],
#                              ['BB', '', 49, ('Th', '4h')]],
#                  'Stakes': (0.02, 0.05),
#                  'WTSD': True,
#                  'Winner': ['HJ', None]},
#   '4474516876': {'Action': [['UTGr2', 'LJf', 'HJf', 'BUf', 'SBf', 'BBc1'],
#                             ['BBx', 'UTGb1', 'BBf']],
#                  'Board': None,
#                  'Players': [['HJ', 'Hero', 49, ('7h', '9d')],
#                              ['BU', '', 48, ('7c', '2h')],
#                              ['SB', '', 168, ('2d', 'Td')],
#                              ['BB', '', 148, ('8h', 'Kd')],
#                              ['UTG', '', 97, ('Ks', '8s')],
#                              ['LJ', '', 49, ('8c', 'Qd')]],
#                  'Stakes': (0.02, 0.05),
#                  'WTSD': True,
#                  'Winner': ['UTG']},
#   '4474516913': {'Action': [['UTGf', 'LJr3', 'HJf', 'BUc3', 'SBf', 'BBf'],
#                             ['LJb5', 'BUc5'],
#                             ['LJx', 'BUb13', 'LJc13'],
#                             ['LJx', 'BUb32', 'LJc32']],
#                  'Board': None,
#                  'Players': [['SB', 'Hero', 49, ('5h', 'Jh')],
#                              ['BB', '', 167, ('8s', 'Jd')],
#                              ['UTG', '', 154, ('Js', '4s')],
#                              ['LJ', '', 74, ('2s', '2d')],
#                              ['HJ', '', 48, ('Qh', '3s')],
#                              ['BU', '', 585, ('Ah', '7h')]],
#                  'Stakes': (0.02, 0.05),
#                  'WTSD': True,
#                  'Winner': ['LJ']},
#   '4474516955': {'Action': [['UTGf',
#                              'LJf',
#                              'HJr2',
#                              'BUf',
#                              'SBf',
#                              'BBr2',
#                              'HJc1'],
#                             ['BBb1', 'HJc1'],
#                             ['BBb2', 'HJc2'],
#                             ['BBb5', 'HJc5']],
#                  'Board': None,
#                  'Players': [['BB', '', 161, ('Ac', 'Ah')],
#                              ['UTG', '', 13, ('2d', '4c')],
#                              ['LJ', 'Hero', 49, ('Qs', 'Jd')],
#                              ['HJ', '', 132, ('7c', 'As')],
#                              ['BU', '', 48, ('9h', 'Ks')],
#                              ['SB', '', 166, ('Ad', '2h')]],
#                  'Stakes': (0.02, 0.05),
#                  'WTSD': True,
#                  'Winner': ['BB']},
#   '4474517009': {'Action': [['UTGf', 'LJf', 'HJf', 'BUr3', 'SBf', 'BBc2'],
#                             ['BBx', 'BUb3', 'BBc3'],
#                             ['BBx', 'BUx'],
#                             ['BBb6', 'BUc6']],
#                  'Board': None,
#                  'Players': [['SB', 'Hero', 49, ('8h', 'Tc')],
#                              ['BB', '', 252, ('Ah', '9c')],
#                              ['UTG', '', 189, ('5h', '6s')],
#                              ['LJ', '', 48, ('Qh', '9h')],
#                              ['HJ', '', 56, ('4c', 'Ks')],
#                              ['BU', '', 100, ('As', 'Jc')]],
#                  'Stakes': (0.02, 0.05),
#                  'WTSD': True,
#                  'Winner': ['BU', 'BB']},
#   '4474517029': {'Action': [['UTGf', 'LJf', 'HJf', 'BUf', 'SBr3', 'BBf']],
#                  'Board': None,
#                  'Players': [['LJ', '', 100, ('3s', '6s')],
#                              ['HJ', '', 83, ('9s', 'Jc')],
#                              ['BU', '', 76, ('Ks', '8d')],
#                              ['SB', '', 207, ('3c', '3h')],
#                              ['BB', 'Hero', 48, ('Qd', '8c')],
#                              ['UTG', '', 189, ('2c', '6c')]],
#                  'Stakes': (0.02, 0.05),
#                  'WTSD': True,
#                  'Winner': ['SB']},
#   '4474517054': {'Action': [['UTGf', 'LJf', 'HJf', 'BUf', 'SBf']],
#                  'Board': None,
#                  'Players': [['LJ', '', 48, ('8s', '2d')],
#                              ['HJ', '', 80, ('Kh', '5s')],
#                              ['BU', 'Hero', 47, ('5c', 'Jh')],
#                              ['SB', '', 153, ('Td', '6c')],
#                              ['BB', '', 100, ('2s', '9d')],
#                              ['UTG', '', 99, ('2h', 'Kd')]],
#                  'Stakes': (0.02, 0.05),
#                  'WTSD': True,
#                  'Winner': ['BB', None]},
#   '4474517109': {'Action': [['UTGr3',
#                              'LJr47',
#                              'HJf',
#                              'BUf',
#                              'SBf',
#                              'BBf',
#                              'UTGc44']],
#                  'Board': ['Qc', '8h', 'Jd', '3d', '9s'],
#                  'Players': [['LJ', 'Hero', 47, ('Qs', 'Ac')],
#                              ['HJ', '', 103, ('6h', 'Jc')],
#                              ['BU', '', 79, ('5h', '5d')],
#                              ['SB', '', 35, ('Jh', '4c')],
#                              ['BB', '', 76, ('7c', '6c')],
#                              ['UTG', '', 99, ('Kh', 'As')]],
#                  'Stakes': (0.02, 0.05),
#                  'WTSD': True,
#                  'Winner': ['LJ', None]}}]

# %%
def _get_hero_pos(players):
    for player in players:
        if player[1] == 'Hero':
            return player[0]

def _hero_raise_pre(pre_action, pos):
    for action in pre_action:
        if (pos + "r" in action or pos + "b" in action):
        #if (pos + "f" in action):
            return True
        
    return False


def get_hero_VPIPed(hands):
    vpiped_hands = []
    for hh in hands:
        for hand in hh.values():
            pos = _get_hero_pos(hand['Players'])
            if _hero_raise_pre(hand['Action'][0], pos):
                vpiped_hands.append(hand)
    return vpiped_hands

def get_hero_VPIPed_hands(hands):
    vpiped_hands = []
    for hand in hands:
        for player in hand['Players']:
            if player[1] == 'Hero':
                vpiped_hands.append(player[3])
    return vpiped_hands
            
        
            
hero_vpip = get_hero_VPIPed(hands)
hero_vpip_hands = get_hero_VPIPed_hands(hero_vpip)

# %%
pprint(hero_vpip)
# Out:
# [{'Action': [['UTGf', 'LJc1', 'HJf', 'BUf', 'SBf', 'BBr50', 'LJf']],
#   'Board': None,
#   'Players': [['BB', 'Hero', 51, ('Kc', 'As')],
#               ['UTG', '', 99, ('4h', '2d')],
#               ['LJ', '', 50, ('8d', 'Jh')],
#               ['HJ', '', 127, ('Qs', '2c')],
#               ['BU', '', 224, ('Jc', '6c')],
#               ['SB', '', 103, ('3c', '7c')]],
#   'Stakes': (0.02, 0.05),
#   'WTSD': True,
#   'Winner': ['BB', 'BB']},
#  {'Action': [['UTGr3', 'LJf', 'HJc3', 'BUf', 'SBr15', 'BBf', 'UTGc12', 'HJf'],
#              ['SBb10', 'UTGc10'],
#              ['SBx', 'UTGx'],
#              ['SBb73', 'UTGf']],
#   'Board': ['Ts', 'Ah', '4c', 'Kd', '6c'],
#   'Players': [['BU', '', 689, ('5d', 'Kh')],
#               ['SB', 'Hero', 99, ('9h', '9s')],
#               ['BB', '', 109, ('Jd', '6h')],
#               ['UTG', '', 101, ('7s', '7d')],
#               ['LJ', '', 88, ('7h', '5c')],
#               ['HJ', '', 51, ('As', '3s')]],
#   'Stakes': (0.02, 0.05),
#   'WTSD': True,
#   'Winner': ['SB', None]},
#  {'Action': [['UTGf', 'LJf', 'HJf', 'BUr3', 'SBr11', 'BBr49', 'BUf', 'SBf']],
#   'Board': None,
#   'Players': [['SB', '', 97, ('Ah', 'Td')],
#               ['BB', 'Hero', 50, ('9s', '9c')],
#               ['UTG', '', 88, ('5s', 'Qc')],
#               ['LJ', '', 114, ('3s', '8c')],
#               ['HJ', '', 73, ('Qh', '4c')],
#               ['BU', '', 100, ('7c', 'Th')]],
#   'Stakes': (0.02, 0.05),
#   'WTSD': True,
#   'Winner': ['BB']},
#  {'Action': [['UTGf', 'LJf', 'HJf', 'BUf', 'SBr63', 'BBf']],
#   'Board': None,
#   'Players': [['SB', 'Hero', 64, ('Kh', 'Qs')],
#               ['BB', '', 34, ('8c', 'Kd')],
#               ['UTG', '', 113, ('3d', '6c')],
#               ['LJ', '', 112, ('8h', '2c')],
#               ['HJ', '', 93, ('6h', '8d')],
#               ['BU', '', 97, ('4s', 'Tc')]],
#   'Stakes': (0.02, 0.05),
#   'WTSD': True,
#   'Winner': ['SB']},
#  {'Action': [['UTGr2', 'LJf', 'HJr47', 'BUf', 'SBf', 'BBf', 'UTGf']],
#   'Board': None,
#   'Players': [['HJ', 'Hero', 47, ('Qh', 'Jh')],
#               ['BU', '', 320, ('3s', '8d')],
#               ['SB', '', 100, ('3d', 'Th')],
#               ['BB', '', 78, ('9h', '8c')],
#               ['UTG', '', 120, ('9d', 'Qd')],
#               ['LJ', '', 60, ('5h', '8s')]],
#   'Stakes': (0.02, 0.05),
#   'WTSD': True,
#   'Winner': ['HJ', 'HJ']},
#  {'Action': [['UTGf', 'LJf', 'HJf', 'BUr47', 'SBf', 'BBf']],
#   'Board': None,
#   'Players': [['BU', 'Hero', 47, ('8d', '8c')],
#               ['SB', '', 207, ('3d', '2s')],
#               ['BB', '', 56, ('Qc', '9s')],
#               ['UTG', '', 121, ('As', '4d')],
#               ['LJ', '', 116, ('3h', 'Ts')],
#               ['HJ', '', 115, ('6h', 'Th')]],
#   'Stakes': (0.02, 0.05),
#   'WTSD': True,
#   'Winner': ['BU', None]},
#  {'Action': [['UTGf', 'LJr3', 'HJf', 'BUr50', 'SBf', 'BBf', 'LJf']],
#   'Board': None,
#   'Players': [['UTG', '', 99, ('7h', 'Jd')],
#               ['LJ', '', 76, ('8d', '9d')],
#               ['HJ', '', 100, ('5d', '8c')],
#               ['BU', 'Hero', 50, ('Ac', 'Qh')],
#               ['SB', '', 150, ('Tc', '8s')],
#               ['BB', '', 173, ('Td', '3h')]],
#   'Stakes': (0.02, 0.05),
#   'WTSD': True,
#   'Winner': ['BU', 'BU']},
#  {'Action': [['UTGf', 'LJf', 'HJr3', 'BUc3', 'SBr47', 'BBf', 'HJf', 'BUf']],
#   'Board': None,
#   'Players': [['BU', '', 220, ('8d', '7d')],
#               ['SB', 'Hero', 48, ('Ah', 'Th')],
#               ['BB', '', 122, ('4h', '5s')],
#               ['UTG', '', 217, ('9h', 'Jh')],
#               ['LJ', '', 543, ('4d', '2s')],
#               ['HJ', '', 320, ('Ts', 'Jd')]],
#   'Stakes': (0.02, 0.05),
#   'WTSD': True,
#   'Winner': ['SB']},
#  {'Action': [['UTGc1', 'LJf', 'HJr55', 'BUf', 'SBf', 'BBf', 'UTGf']],
#   'Board': None,
#   'Players': [['SB', '', 322, ('Js', 'Kd')],
#               ['BB', '', 100, ('Jh', '3s')],
#               ['UTG', '', 113, ('2d', 'Qd')],
#               ['LJ', '', 121, ('9h', '7s')],
#               ['HJ', 'Hero', 55, ('Kc', 'Ad')],
#               ['BU', '', 255, ('Tc', 'Qh')]],
#   'Stakes': (0.02, 0.05),
#   'WTSD': True,
#   'Winner': ['HJ', 'HJ']},
#  {'Action': [['UTGf', 'LJf', 'HJf', 'BUf', 'SBr44', 'BBf']],
#   'Board': None,
#   'Players': [['BB', '', 73, ('Kc', '8s')],
#               ['UTG', '', 161, ('7s', 'Ac')],
#               ['LJ', '', 170, ('2h', '7c')],
#               ['HJ', '', 113, ('8h', '4d')],
#               ['BU', '', 97, ('Ad', '8c')],
#               ['SB', 'Hero', 44, ('Kd', 'Kh')]],
#   'Stakes': (0.02, 0.05),
#   'WTSD': True,
#   'Winner': ['SB', 'SB']},
#  {'Action': [['UTGf', 'LJf', 'HJr96', 'BUf', 'SBf', 'BBf']],
#   'Board': None,
#   'Players': [['HJ', 'Hero', 96, ('Kc', 'Ad')],
#               ['BU', '', 80, ('As', '2d')],
#               ['SB', '', 88, ('2c', '3s')],
#               ['BB', '', 50, ('Tc', 'Ac')],
#               ['UTG', '', 107, ('Td', '9s')],
#               ['LJ', '', 99, ('4d', '6d')]],
#   'Stakes': (0.02, 0.05),
#   'WTSD': True,
#   'Winner': ['HJ', None]},
#  {'Action': [['UTGf', 'LJf', 'HJr50', 'BUf', 'SBf', 'BBf']],
#   'Board': None,
#   'Players': [['SB', '', 46, ('Jh', '7h')],
#               ['BB', '', 123, ('7d', '6s')],
#               ['UTG', '', 256, ('8h', '2h')],
#               ['LJ', '', 147, ('6c', 'Th')],
#               ['HJ', 'Hero', 50, ('9d', '9s')],
#               ['BU', '', 100, ('2s', '4d')]],
#   'Stakes': (0.02, 0.05),
#   'WTSD': True,
#   'Winner': ['HJ', None]},
#  {'Action': [['UTGf', 'LJf', 'HJf', 'BUr3', 'SBr48', 'BBf', 'BUf']],
#   'Board': None,
#   'Players': [['HJ', '', 117, ('Kh', '4s')],
#               ['BU', '', 232, ('Kd', 'Qc')],
#               ['SB', 'Hero', 49, ('Tc', 'Ac')],
#               ['BB', '', 82, ('8s', '7c')],
#               ['UTG', '', 86, ('Qs', '9d')],
#               ['LJ', '', 100, ('2h', '3s')]],
#   'Stakes': (0.02, 0.05),
#   'WTSD': True,
#   'Winner': ['SB']},
#  {'Action': [['UTGf', 'LJf', 'HJr2', 'BUf', 'SBr51', 'BBf', 'HJf']],
#   'Board': None,
#   'Players': [['LJ', '', 105, ('Ac', '6s')],
#               ['HJ', '', 251, ('Jd', 'Qd')],
#               ['BU', '', 100, ('6d', '4s')],
#               ['SB', 'Hero', 51, ('7d', '7s')],
#               ['BB', '', 111, ('6h', '4c')],
#               ['UTG', '', 46, ('Th', '2d')]],
#   'Stakes': (0.02, 0.05),
#   'WTSD': True,
#   'Winner': ['SB', 'SB']},
#  {'Action': [['UTGf', 'LJf', 'HJf', 'BUf', 'SBr4', 'BBr54', 'SBf']],
#   'Board': None,
#   'Players': [['BB', 'Hero', 55, ('Ad', 'Jh')],
#               ['UTG', '', 142, ('9d', 'Qh')],
#               ['LJ', '', 112, ('6c', '7h')],
#               ['HJ', '', 226, ('4d', '3c')],
#               ['BU', '', 166, ('2c', 'Qs')],
#               ['SB', '', 264, ('7c', 'Js')]],
#   'Stakes': (0.02, 0.05),
#   'WTSD': True,
#   'Winner': ['BB']},
#  {'Action': [['UTGr3', 'LJf', 'HJf', 'BUc3', 'SBf', 'BBr49', 'UTGf', 'BUf']],
#   'Board': None,
#   'Players': [['BB', 'Hero', 50, ('Jc', 'Ad')],
#               ['UTG', '', 135, ('Tc', 'Qh')],
#               ['LJ', '', 96, ('7c', '5h')],
#               ['HJ', '', 52, ('2h', '5c')],
#               ['BU', '', 41, ('Ah', '9s')],
#               ['SB', '', 248, ('8d', 'Ac')]],
#   'Stakes': (0.02, 0.05),
#   'WTSD': True,
#   'Winner': ['BB', None]},
#  {'Action': [['UTGf', 'LJf', 'HJr2', 'BUr50', 'SBf', 'BBr99', 'HJf']],
#   'Board': None,
#   'Players': [['LJ', '', 228, ('9h', 'Ks')],
#               ['HJ', '', 44, ('Qh', '8s')],
#               ['BU', 'Hero', 50, ('Th', 'As')],
#               ['SB', '', 81, ('Ts', '9d')],
#               ['BB', '', 100, ('Ad', 'Kh')],
#               ['UTG', '', 140, ('6d', '5s')]],
#   'Stakes': (0.02, 0.05),
#   'WTSD': True,
#   'Winner': ['BU', 'BU']},
#  {'Action': [['UTGr50', 'LJf', 'HJf', 'BUf', 'SBf', 'BBf']],
#   'Board': None,
#   'Players': [['BU', '', 100, ('Td', '6s')],
#               ['SB', '', 636, ('5s', '7h')],
#               ['BB', '', 47, ('2c', '5h')],
#               ['UTG', 'Hero', 50, ('Js', 'Qs')],
#               ['LJ', '', 100, ('Qh', '3c')],
#               ['HJ', '', 92, ('4c', '5d')]],
#   'Stakes': (0.02, 0.05),
#   'WTSD': True,
#   'Winner': ['UTG', 'UTG']},
#  {'Action': [['UTGf', 'LJr49', 'HJf', 'BUf', 'SBf', 'BBf']],
#   'Board': None,
#   'Players': [['SB', '', 226, ('4c', 'Jd')],
#               ['BB', '', 56, ('6s', '3s')],
#               ['UTG', '', 90, ('4h', '6c')],
#               ['LJ', 'Hero', 49, ('Qh', 'Kh')],
#               ['HJ', '', 54, ('9h', '6d')],
#               ['BU', '', 100, ('Kc', 'Td')]],
#   'Stakes': (0.02, 0.05),
#   'WTSD': True,
#   'Winner': [None, 'LJ']},
#  {'Action': [['UTGf', 'LJc1', 'HJr50', 'BUf', 'SBf', 'BBf', 'LJf']],
#   'Board': None,
#   'Players': [['LJ', '', 106, ('9c', 'Th')],
#               ['HJ', 'Hero', 50, ('Jc', 'Ad')],
#               ['BU', '', 105, ('Qd', '4d')],
#               ['SB', '', 199, ('9d', '4h')],
#               ['BB', '', 100, ('7d', '7s')],
#               ['UTG', '', 50, ('6s', '8h')]],
#   'Stakes': (0.02, 0.05),
#   'WTSD': True,
#   'Winner': ['HJ']},
#  {'Action': [['UTGr50', 'LJf', 'HJf', 'BUf', 'SBf', 'BBf']],
#   'Board': None,
#   'Players': [['SB', '', 100, ('Qs', '9c')],
#               ['BB', '', 58, ('7h', '6s')],
#               ['UTG', 'Hero', 50, ('Th', 'Ts')],
#               ['LJ', '', 100, ('9h', '2c')],
#               ['HJ', '', 91, ('7s', '5d')],
#               ['BU', '', 83, ('6d', 'Jc')]],
#   'Stakes': (0.02, 0.05),
#   'WTSD': True,
#   'Winner': ['UTG']},
#  {'Action': [['UTGr50', 'LJf', 'HJf', 'BUf', 'SBf', 'BBf']],
#   'Board': None,
#   'Players': [['SB', '', 205, ('Ts', 'Kh')],
#               ['BB', '', 207, ('9h', '4h')],
#               ['UTG', 'Hero', 50, ('Ah', 'Ac')],
#               ['LJ', '', 200, ('5s', '7h')],
#               ['HJ', '', 40, ('6d', 'Jd')],
#               ['BU', '', 108, ('2c', '8c')]],
#   'Stakes': (0.02, 0.05),
#   'WTSD': True,
#   'Winner': ['UTG', None]},
#  {'Action': [['UTGf', 'LJf', 'HJr3', 'BUf', 'SBr48', 'BBf', 'HJf']],
#   'Board': None,
#   'Players': [['SB', 'Hero', 49, ('Ah', 'Qd')],
#               ['BB', '', 99, ('Qh', '5s')],
#               ['UTG', '', 205, ('7h', 'Js')],
#               ['LJ', '', 97, ('Jc', '7s')],
#               ['HJ', '', 110, ('Ts', 'Kd')],
#               ['BU', '', 292, ('Tc', '6c')]],
#   'Stakes': (0.02, 0.05),
#   'WTSD': True,
#   'Winner': ['SB']},
#  {'Action': [['UTGf', 'LJf', 'HJf', 'BUr51', 'SBf', 'BBf']],
#   'Board': None,
#   'Players': [['LJ', '', 92, ('5s', 'Jd')],
#               ['HJ', '', 190, ('9s', 'Td')],
#               ['BU', 'Hero', 51, ('2d', 'Ad')],
#               ['SB', '', 42, ('6s', 'Qh')],
#               ['BB', '', 269, ('Js', '4s')],
#               ['UTG', '', 194, ('7s', '9c')]],
#   'Stakes': (0.02, 0.05),
#   'WTSD': True,
#   'Winner': ['BU']},
#  {'Action': [['UTGf', 'LJr3', 'HJf', 'BUc3', 'SBr51', 'BBf', 'LJf', 'BUf']],
#   'Board': None,
#   'Players': [['UTG', '', 227, ('2h', '6d')],
#               ['LJ', '', 68, ('Jc', 'Th')],
#               ['HJ', '', 248, ('4c', '7h')],
#               ['BU', '', 558, ('3d', '3h')],
#               ['SB', 'Hero', 51, ('Qh', 'As')],
#               ['BB', '', 105, ('3c', '7d')]],
#   'Stakes': (0.02, 0.05),
#   'WTSD': True,
#   'Winner': [None, 'SB']},
#  {'Action': [['UTGf', 'LJf', 'HJr55', 'BUf', 'SBf', 'BBf']],
#   'Board': None,
#   'Players': [['BB', '', 98, ('Ad', '7c')],
#               ['UTG', '', 81, ('7d', '2d')],
#               ['LJ', '', 140, ('Kh', '6c')],
#               ['HJ', 'Hero', 55, ('Ts', 'Th')],
#               ['BU', '', 105, ('4d', '8s')],
#               ['SB', '', 109, ('Td', '4h')]],
#   'Stakes': (0.02, 0.05),
#   'WTSD': True,
#   'Winner': ['HJ']},
#  {'Action': [['UTGf', 'LJf', 'HJr50', 'BUf', 'SBc49', 'BBf']],
#   'Board': None,
#   'Players': [['LJ', '', 129, ('9d', 'Th')],
#               ['HJ', 'Hero', 50, ('Ks', 'Ad')],
#               ['BU', '', 92, ('Kd', '4c')],
#               ['SB', '', 90, ('9c', 'Ac')],
#               ['BB', '', 123, ('3c', '8d')],
#               ['UTG', '', 182, ('5d', '2s')]],
#   'Stakes': (0.02, 0.05),
#   'WTSD': True,
#   'Winner': ['HJ']},
#  {'Action': [['UTGf', 'LJf', 'HJf', 'BUf', 'SBc1', 'BBr49', 'SBf']],
#   'Board': None,
#   'Players': [['LJ', '', 129, ('Td', '4s')],
#               ['HJ', '', 107, ('4d', '9c')],
#               ['BU', '', 104, ('3d', '8s')],
#               ['SB', '', 50, ('5c', 'Kc')],
#               ['BB', 'Hero', 50, ('Ad', 'Ac')],
#               ['UTG', '', 100, ('8h', 'Kh')]],
#   'Stakes': (0.02, 0.05),
#   'WTSD': True,
#   'Winner': ['BB', None]},
#  {'Action': [['UTGf', 'LJr2', 'HJf', 'BUc2', 'SBf', 'BBr50', 'LJf', 'BUf']],
#   'Board': None,
#   'Players': [['SB', '', 98, ('4s', '8h')],
#               ['BB', 'Hero', 51, ('Tc', 'Ah')],
#               ['UTG', '', 284, ('7h', '4h')],
#               ['LJ', '', 140, ('3d', '3h')],
#               ['HJ', '', 108, ('2s', 'Kh')],
#               ['BU', '', 93, ('Jc', '5c')]],
#   'Stakes': (0.02, 0.05),
#   'WTSD': True,
#   'Winner': ['BB', None]},
#  {'Action': [['UTGf', 'LJf', 'HJf', 'BUr55', 'SBf', 'BBf']],
#   'Board': None,
#   'Players': [['BU', 'Hero', 55, ('3d', '3s')],
#               ['SB', '', 100, ('Kd', 'Qd')],
#               ['BB', '', 238, ('4c', '6s')],
#               ['UTG', '', 112, ('Qh', '9d')],
#               ['LJ', '', 55, ('2h', '6h')],
#               ['HJ', '', 608, ('5h', 'Jd')]],
#   'Stakes': (0.02, 0.05),
#   'WTSD': True,
#   'Winner': ['BU']},
#  {'Action': [['UTGf', 'LJr55', 'HJf', 'BUf', 'SBf', 'BBf']],
#   'Board': None,
#   'Players': [['SB', '', 142, ('6d', '3c')],
#               ['BB', '', 104, ('3d', 'Ts')],
#               ['UTG', '', 207, ('9d', '6s')],
#               ['LJ', 'Hero', 55, ('Qh', 'Ah')],
#               ['HJ', '', 97, ('2h', 'Kd')],
#               ['BU', '', 95, ('6c', '8c')]],
#   'Stakes': (0.02, 0.05),
#   'WTSD': True,
#   'Winner': ['LJ', None]},
#  {'Action': [['UTGr3', 'LJc3', 'HJr49', 'BUf', 'SBf', 'BBf', 'UTGf', 'LJf']],
#   'Board': None,
#   'Players': [['BB', '', 311, ('2s', '8c')],
#               ['UTG', '', 134, ('Kd', 'Ts')],
#               ['LJ', '', 86, ('9s', 'Ac')],
#               ['HJ', 'Hero', 49, ('Ad', '4d')],
#               ['BU', '', 126, ('5c', 'As')],
#               ['SB', '', 142, ('Tc', '4c')]],
#   'Stakes': (0.02, 0.05),
#   'WTSD': True,
#   'Winner': ['HJ']},
#  {'Action': [['UTGr3', 'LJf', 'HJc3', 'BUf', 'SBf', 'BBr55', 'UTGf', 'HJc53']],
#   'Board': None,
#   'Players': [['BB', 'Hero', 56, ('Ks', 'Qc')],
#               ['UTG', '', 110, ('Ac', '3c')],
#               ['LJ', '', 177, ('4d', '5h')],
#               ['HJ', '', 99, ('Ah', '4c')],
#               ['BU', '', 103, ('7c', 'Qh')],
#               ['SB', '', 141, ('8s', '2c')]],
#   'Stakes': (0.02, 0.05),
#   'WTSD': True,
#   'Winner': ['HJ']},
#  {'Action': [['UTGf', 'LJr51', 'HJf', 'BUr132', 'SBf', 'BBf']],
#   'Board': ['Ad', 'Qh', 'Tc', '6s', '5h'],
#   'Players': [['HJ', '', 99, ('2h', 'Jh')],
#               ['BU', '', 132, ('8h', '8c')],
#               ['SB', '', 88, ('4d', '9s')],
#               ['BB', '', 156, ('Ks', 'Qd')],
#               ['UTG', '', 115, ('Kh', '6d')],
#               ['LJ', 'Hero', 51, ('Js', 'Jd')]],
#   'Stakes': (0.02, 0.05),
#   'WTSD': True,
#   'Winner': ['LJ', None]},
#  {'Action': [['UTGr2', 'LJf', 'HJf', 'BUf', 'SBf', 'BBr50', 'UTGc49']],
#   'Board': None,
#   'Players': [['SB', '', 89, ('5s', '7c')],
#               ['BB', 'Hero', 51, ('Kc', 'Ks')],
#               ['UTG', '', 60, ('Ac', '4c')],
#               ['LJ', '', 107, ('Ah', '2s')],
#               ['HJ', '', 93, ('Kh', '6s')],
#               ['BU', '', 32, ('7d', '8s')]],
#   'Stakes': (0.02, 0.05),
#   'WTSD': True,
#   'Winner': ['BB']},
#  {'Action': [['UTGf', 'LJc1', 'HJf', 'BUc1', 'SBf', 'BBr50', 'LJf', 'BUf']],
#   'Board': None,
#   'Players': [['BB', 'Hero', 51, ('Kh', 'Jh')],
#               ['UTG', '', 104, ('Tc', '7c')],
#               ['LJ', '', 58, ('9c', 'Ts')],
#               ['HJ', '', 96, ('7h', '2h')],
#               ['BU', '', 107, ('9s', '7s')],
#               ['SB', '', 264, ('9h', 'Ad')]],
#   'Stakes': (0.02, 0.05),
#   'WTSD': True,
#   'Winner': ['BB', None]},
#  {'Action': [['UTGf', 'LJf', 'HJf', 'BUr3', 'SBr53', 'BBf', 'BUf']],
#   'Board': None,
#   'Players': [['BB', '', 104, ('4h', '4s')],
#               ['UTG', '', 87, ('3h', 'Jc')],
#               ['LJ', '', 35, ('Ac', '3d')],
#               ['HJ', '', 127, ('7d', '9s')],
#               ['BU', '', 84, ('Kh', 'Ts')],
#               ['SB', 'Hero', 53, ('Ad', '5d')]],
#   'Stakes': (0.02, 0.05),
#   'WTSD': True,
#   'Winner': ['SB', None]},
#  {'Action': [['UTGf', 'LJr3', 'HJf', 'BUf', 'SBr12', 'BBr44', 'LJr82', 'SBf']],
#   'Board': None,
#   'Players': [['SB', '', 88, ('Tc', 'Th')],
#               ['BB', 'Hero', 45, ('Ah', 'Qs')],
#               ['UTG', '', 47, ('9c', 'Ac')],
#               ['LJ', '', 85, ('Ks', 'Kc')],
#               ['HJ', '', 88, ('Qd', '8c')],
#               ['BU', '', 48, ('4c', 'Js')]],
#   'Stakes': (0.02, 0.05),
#   'WTSD': True,
#   'Winner': ['SB', 'BB']},
#  {'Action': [['UTGr50', 'LJf', 'HJf', 'BUb39', 'SBf', 'BBf']],
#   'Board': None,
#   'Players': [['BB', '', 57, ('Jc', '5d')],
#               ['UTG', 'Hero', 50, ('9c', '9s')],
#               ['LJ', '', 115, ('4s', '8h')],
#               ['HJ', '', 137, ('2d', '5h')],
#               ['BU', '', 39, ('Ah', 'Jh')],
#               ['SB', '', 195, ('8c', '7s')]],
#   'Stakes': (0.02, 0.05),
#   'WTSD': True,
#   'Winner': ['BU']},
#  {'Action': [['UTGf', 'LJf', 'HJr46', 'BUf', 'SBf', 'BBf']],
#   'Board': None,
#   'Players': [['HJ', 'Hero', 46, ('Ad', 'Ah')],
#               ['BU', '', 34, ('6c', 'Kc')],
#               ['SB', '', 102, ('Tc', '3c')],
#               ['BB', '', 134, ('4h', '5c')],
#               ['UTG', '', 100, ('Th', '4s')],
#               ['LJ', '', 144, ('6s', '3s')]],
#   'Stakes': (0.02, 0.05),
#   'WTSD': True,
#   'Winner': ['HJ']},
#  {'Action': [['UTGr3', 'LJf', 'HJf', 'BUr46', 'SBf', 'BBf', 'UTGf']],
#   'Board': None,
#   'Players': [['BB', '', 147, ('Qh', '4s')],
#               ['UTG', '', 68, ('Qc', '9d')],
#               ['LJ', '', 85, ('Kc', '4d')],
#               ['HJ', '', 102, ('7s', '8d')],
#               ['BU', 'Hero', 46, ('Th', 'Td')],
#               ['SB', '', 150, ('Ac', '6h')]],
#   'Stakes': (0.02, 0.05),
#   'WTSD': True,
#   'Winner': ['BU']},
#  {'Action': [['UTGr50', 'LJf', 'HJf', 'BUf', 'SBf', 'BBf']],
#   'Board': None,
#   'Players': [['LJ', '', 178, ('9c', '3c')],
#               ['HJ', '', 23, ('8d', '6s')],
#               ['BU', '', 129, ('Jc', '6h')],
#               ['SB', '', 102, ('4c', 'Qd')],
#               ['BB', '', 100, ('Jd', 'Kd')],
#               ['UTG', 'Hero', 50, ('Ac', 'Qc')]],
#   'Stakes': (0.02, 0.05),
#   'WTSD': True,
#   'Winner': ['UTG', None]},
#  {'Action': [['UTGf', 'LJf', 'HJr3', 'BUf', 'SBr52', 'BBf', 'HJf']],
#   'Board': None,
#   'Players': [['SB', 'Hero', 52, ('Ah', '5h')],
#               ['BB', '', 214, ('Qd', '8s')],
#               ['UTG', '', 368, ('2s', 'Jh')],
#               ['LJ', '', 86, ('4s', '6c')],
#               ['HJ', '', 155, ('Js', 'Td')],
#               ['BU', '', 100, ('7c', 'Kc')]],
#   'Stakes': (0.02, 0.05),
#   'WTSD': True,
#   'Winner': ['SB', None]},
#  {'Action': [['UTGf', 'LJr47', 'HJf', 'BUf', 'SBf', 'BBf']],
#   'Board': None,
#   'Players': [['BU', '', 46, ('4d', '9h')],
#               ['SB', '', 575, ('2d', 'Qd')],
#               ['BB', '', 105, ('6h', '6c')],
#               ['UTG', '', 46, ('5c', 'Kd')],
#               ['LJ', 'Hero', 47, ('Ah', 'Jc')],
#               ['HJ', '', 84, ('7c', '6s')]],
#   'Stakes': (0.02, 0.05),
#   'WTSD': True,
#   'Winner': ['LJ']},
#  {'Action': [['UTGr3', 'LJf', 'HJf', 'BUf', 'SBf', 'BBr48', 'UTGb43']],
#   'Board': None,
#   'Players': [['BB', 'Hero', 49, ('Jh', 'As')],
#               ['UTG', '', 46, ('9h', 'Kh')],
#               ['LJ', '', 63, ('4h', '3s')],
#               ['HJ', '', 190, ('Js', 'Qd')],
#               ['BU', '', 313, ('8d', '7s')],
#               ['SB', '', 45, ('7d', '7c')]],
#   'Stakes': (0.02, 0.05),
#   'WTSD': True,
#   'Winner': ['BB', None, 'BB']},
#  {'Action': [['UTGf', 'LJf', 'HJf', 'BUf', 'SBr48', 'BBf']],
#   'Board': None,
#   'Players': [['SB', 'Hero', 48, ('Qd', 'Ac')],
#               ['BB', '', 496, ('Kd', '7h')],
#               ['UTG', '', 204, ('Ks', '4s')],
#               ['LJ', '', 167, ('Td', '3h')],
#               ['HJ', '', 41, ('Qh', '2c')],
#               ['BU', '', 118, ('5s', '8d')]],
#   'Stakes': (0.02, 0.05),
#   'WTSD': True,
#   'Winner': ['SB', None]},
#  {'Action': [['UTGr48', 'LJf', 'HJf', 'BUf', 'SBf', 'BBf']],
#   'Board': None,
#   'Players': [['LJ', '', 497, ('Ts', '9d')],
#               ['HJ', '', 105, ('9s', 'Ks')],
#               ['BU', '', 101, ('Kd', '9h')],
#               ['SB', '', 151, ('5d', 'Jh')],
#               ['BB', '', 145, ('5c', 'Js')],
#               ['UTG', 'Hero', 48, ('As', 'Qh')]],
#   'Stakes': (0.02, 0.05),
#   'WTSD': True,
#   'Winner': ['UTG']},
#  {'Action': [['UTGf', 'LJr3', 'HJf', 'BUr47', 'SBf', 'BBc46', 'LJb38']],
#   'Board': ['2s', '2c', '4s', 'Kh', '6c'],
#   'Players': [['UTG', '', 87, ('Qd', '4h')],
#               ['LJ', '', 41, ('Th', 'Jh')],
#               ['HJ', '', 44, ('7c', '9h')],
#               ['BU', 'Hero', 47, ('Js', 'As')],
#               ['SB', '', 131, ('5d', '4c')],
#               ['BB', '', 55, ('Ac', 'Kd')]],
#   'Stakes': (0.02, 0.05),
#   'WTSD': True,
#   'Winner': ['BB', None]},
#  {'Action': [['UTGc1',
#               'LJr4',
#               'HJf',
#               'BUf',
#               'SBf',
#               'BBr50',
#               'UTGr59',
#               'LJc56']],
#   'Board': None,
#   'Players': [['SB', '', 101, ('Jd', '3h')],
#               ['BB', 'Hero', 51, ('Qh', 'Ad')],
#               ['UTG', '', 60, ('Kc', 'Qd')],
#               ['LJ', '', 229, ('Ah', 'Ks')],
#               ['HJ', '', 77, ('8d', '5c')],
#               ['BU', '', 150, ('3s', 'Ac')]],
#   'Stakes': (0.02, 0.05),
#   'WTSD': True,
#   'Winner': [None, 'BB']},
#  {'Action': [['UTGf', 'LJr49', 'HJf', 'BUf', 'SBf', 'BBf']],
#   'Board': None,
#   'Players': [['BU', '', 123, ('Ah', '5h')],
#               ['SB', '', 94, ('7d', 'Jd')],
#               ['BB', '', 36, ('6s', '2d')],
#               ['UTG', '', 87, ('Qs', '5d')],
#               ['LJ', 'Hero', 49, ('8d', '8h')],
#               ['HJ', '', 66, ('4s', '3d')]],
#   'Stakes': (0.02, 0.05),
#   'WTSD': True,
#   'Winner': ['LJ']},
#  {'Action': [['UTGf', 'LJf', 'HJr48', 'BUf', 'SBf', 'BBf']],
#   'Board': None,
#   'Players': [['HJ', 'Hero', 48, ('Qs', 'Kc')],
#               ['BU', '', 38, ('6d', '5d')],
#               ['SB', '', 102, ('2c', 'Ah')],
#               ['BB', '', 112, ('Kh', '9s')],
#               ['UTG', '', 139, ('2h', '7c')],
#               ['LJ', '', 145, ('Ts', 'Qd')]],
#   'Stakes': (0.02, 0.05),
#   'WTSD': True,
#   'Winner': ['HJ']},
#  {'Action': [['UTGf', 'LJf', 'HJc1', 'BUf', 'SBf', 'BBr48', 'HJf']],
#   'Board': None,
#   'Players': [['SB', '', 103, ('4s', '9s')],
#               ['BB', 'Hero', 49, ('2s', 'As')],
#               ['UTG', '', 42, ('Qs', '2c')],
#               ['LJ', '', 241, ('8h', '5c')],
#               ['HJ', '', 44, ('Jh', 'Kh')],
#               ['BU', '', 160, ('Jc', '6c')]],
#   'Stakes': (0.02, 0.05),
#   'WTSD': True,
#   'Winner': ['BB', None]},
#  {'Action': [['UTGr3', 'LJf', 'HJr49', 'BUr203', 'SBf', 'BBf', 'UTGb72']],
#   'Board': None,
#   'Players': [['HJ', 'Hero', 49, ('9s', '9c')],
#               ['BU', '', 203, ('Ac', 'Jc')],
#               ['SB', '', 49, ('Ks', '5c')],
#               ['BB', '', 64, ('2h', '7d')],
#               ['UTG', '', 75, ('Kd', 'Ah')],
#               ['LJ', '', 35, ('8d', '9d')]],
#   'Stakes': (0.02, 0.05),
#   'WTSD': True,
#   'Winner': ['UTG']},
#  {'Action': [['UTGr49', 'LJf', 'HJf', 'BUf', 'SBf', 'BBf']],
#   'Board': None,
#   'Players': [['BB', '', 157, ('4s', '3c')],
#               ['UTG', 'Hero', 49, ('Ad', 'Kc')],
#               ['LJ', '', 312, ('2c', '7s')],
#               ['HJ', '', 206, ('2s', 'Kh')],
#               ['BU', '', 34, ('Js', 'Ks')],
#               ['SB', '', 112, ('Ah', '5d')]],
#   'Stakes': (0.02, 0.05),
#   'WTSD': True,
#   'Winner': ['UTG']},
#  {'Action': [['UTGf', 'LJf', 'HJc1', 'BUf', 'SBc1', 'BBr49', 'HJf', 'SBf']],
#   'Board': None,
#   'Players': [['SB', '', 194, ('As', '6s')],
#               ['BB', 'Hero', 50, ('8s', '8d')],
#               ['UTG', '', 37, ('Tc', '8h')],
#               ['LJ', '', 128, ('3s', 'Ac')],
#               ['HJ', '', 31, ('Ah', '9s')],
#               ['BU', '', 310, ('5d', 'Jd')]],
#   'Stakes': (0.02, 0.05),
#   'WTSD': True,
#   'Winner': ['BB']},
#  {'Action': [['UTGf', 'LJc1', 'HJr4', 'BUr50', 'SBf', 'BBf', 'LJc49', 'HJf']],
#   'Board': ['Ah', 'Jh', '4s', '3c', '2h'],
#   'Players': [['HJ', '', 256, ('Kd', 'Tc')],
#               ['BU', 'Hero', 50, ('As', 'Td')],
#               ['SB', '', 45, ('2s', '7h')],
#               ['BB', '', 151, ('3s', 'Qc')],
#               ['UTG', '', 573, ('Qd', 'Th')],
#               ['LJ', '', 63, ('9c', '9s')]],
#   'Stakes': (0.02, 0.05),
#   'WTSD': True,
#   'Winner': ['BU', None]},
#  {'Action': [['UTGr18', 'LJf', 'HJf', 'BUf', 'SBr50', 'BBf']],
#   'Board': ['Ks', '8s', 'Tc', 'Jc', '7h'],
#   'Players': [['BB', '', 76, ('9d', 'Ac')],
#               ['UTG', '', 18, ('Th', 'Ts')],
#               ['LJ', '', 241, ('2d', '6d')],
#               ['HJ', '', 64, ('3d', '5c')],
#               ['BU', '', 130, ('8d', '4d')],
#               ['SB', 'Hero', 50, ('5d', '5s')]],
#   'Stakes': (0.02, 0.05),
#   'WTSD': True,
#   'Winner': ['UTG', None]},
#  {'Action': [['UTGr31', 'LJf', 'HJf', 'BUf', 'SBf', 'BBf']],
#   'Board': None,
#   'Players': [['SB', '', 63, ('3c', 'Jc')],
#               ['BB', '', 23, ('3s', '2c')],
#               ['UTG', 'Hero', 31, ('Ac', 'Qh')],
#               ['LJ', '', 134, ('Ts', 'Ks')],
#               ['HJ', '', 49, ('8c', 'Kd')],
#               ['BU', '', 48, ('6s', '2s')]],
#   'Stakes': (0.02, 0.05),
#   'WTSD': True,
#   'Winner': ['UTG']},
#  {'Action': [['UTGf', 'LJf', 'HJf', 'BUc1', 'SBr32', 'BBf', 'BUc31']],
#   'Board': None,
#   'Players': [['BU', '', 53, ('5h', 'Ah')],
#               ['SB', 'Hero', 32, ('Qh', 'Qd')],
#               ['BB', '', 46, ('4h', '3h')],
#               ['UTG', '', 99, ('8s', '2c')],
#               ['LJ', '', 47, ('Ts', 'Kc')],
#               ['HJ', '', 49, ('3d', '9d')]],
#   'Stakes': (0.02, 0.05),
#   'WTSD': True,
#   'Winner': ['BU']},
#  {'Action': [['UTGr5', 'LJc5', 'HJf', 'BUr50', 'SBf', 'BBf', 'UTGr118', 'LJf']],
#   'Board': ['Kd', '4h', '4c', '6h', '4d'],
#   'Players': [['SB', '', 81, ('3c', 'Td')],
#               ['BB', '', 128, ('5d', 'Ts')],
#               ['UTG', '', 123, ('Jh', 'Js')],
#               ['LJ', '', 97, ('As', 'Jc')],
#               ['HJ', '', 46, ('2c', 'Qc')],
#               ['BU', 'Hero', 50, ('Tc', 'Ac')]],
#   'Stakes': (0.02, 0.05),
#   'WTSD': True,
#   'Winner': ['UTG', None]},
#  {'Action': [['UTGf', 'LJf', 'HJr50', 'BUf', 'SBf', 'BBf']],
#   'Board': None,
#   'Players': [['SB', '', 152, ('9h', 'Qd')],
#               ['BB', '', 97, ('7h', '2s')],
#               ['UTG', '', 113, ('6c', '2d')],
#               ['LJ', '', 132, ('4c', '2c')],
#               ['HJ', 'Hero', 50, ('Jh', 'Ah')],
#               ['BU', '', 128, ('Ks', '9d')]],
#   'Stakes': (0.02, 0.05),
#   'WTSD': True,
#   'Winner': ['HJ']},
#  {'Action': [['UTGf', 'LJf', 'HJr48', 'BUf', 'SBf', 'BBf']],
#   'Board': None,
#   'Players': [['LJ', '', 123, ('7s', '2s')],
#               ['HJ', 'Hero', 48, ('Jd', 'Ks')],
#               ['BU', '', 62, ('As', 'Tc')],
#               ['SB', '', 49, ('Kd', '4c')],
#               ['BB', '', 235, ('5c', 'Qh')],
#               ['UTG', '', 48, ('3s', '6c')]],
#   'Stakes': (0.02, 0.05),
#   'WTSD': True,
#   'Winner': ['HJ', None]},
#  {'Action': [['UTGf', 'LJc1', 'HJf', 'BUf', 'SBf', 'BBr45', 'LJf']],
#   'Board': None,
#   'Players': [['BU', '', 99, ('2d', '9c')],
#               ['SB', '', 51, ('6c', '7c')],
#               ['BB', 'Hero', 46, ('Js', 'Ad')],
#               ['UTG', '', 48, ('9s', 'Jc')],
#               ['LJ', '', 152, ('Qd', 'Td')],
#               ['HJ', '', 98, ('5s', '2h')]],
#   'Stakes': (0.02, 0.05),
#   'WTSD': True,
#   'Winner': ['BB', None]},
#  {'Action': [['UTGr3', 'LJr47', 'HJf', 'BUf', 'SBf', 'BBc46', 'UTGf']],
#   'Board': None,
#   'Players': [['LJ', 'Hero', 47, ('As', 'Kh')],
#               ['HJ', '', 82, ('2h', '5h')],
#               ['BU', '', 48, ('3h', '8c')],
#               ['SB', '', 73, ('5d', '7d')],
#               ['BB', '', 152, ('Qd', 'Qs')],
#               ['UTG', '', 562, ('Ts', 'Ks')]],
#   'Stakes': (0.02, 0.05),
#   'WTSD': True,
#   'Winner': ['BB']},
#  {'Action': [['UTGf', 'LJf', 'HJf', 'BUr49', 'SBf', 'BBf']],
#   'Board': None,
#   'Players': [['BU', 'Hero', 49, ('Ts', 'Th')],
#               ['SB', '', 46, ('Jc', '9h')],
#               ['BB', '', 485, ('2d', '4c')],
#               ['UTG', '', 148, ('5s', '8d')],
#               ['LJ', '', 92, ('9d', '2h')],
#               ['HJ', '', 175, ('3h', '2s')]],
#   'Stakes': (0.02, 0.05),
#   'WTSD': True,
#   'Winner': ['BU']},
#  {'Action': [['UTGf', 'LJf', 'HJf', 'BUr50', 'SBf', 'BBf']],
#   'Board': None,
#   'Players': [['BB', '', 111, ('3h', '6s')],
#               ['UTG', '', 560, ('7c', 'Th')],
#               ['LJ', '', 103, ('Ah', '5c')],
#               ['HJ', '', 244, ('3d', 'Jc')],
#               ['BU', 'Hero', 50, ('As', '3s')],
#               ['SB', '', 102, ('3c', 'Js')]],
#   'Stakes': (0.02, 0.05),
#   'WTSD': True,
#   'Winner': ['BU']},
#  {'Action': [['UTGf', 'LJc1', 'HJf', 'BUr51', 'SBf', 'BBf', 'LJf']],
#   'Board': None,
#   'Players': [['HJ', '', 65, ('3s', '9d')],
#               ['BU', 'Hero', 51, ('Ac', '6c')],
#               ['SB', '', 101, ('Th', '7d')],
#               ['BB', '', 144, ('6d', '8h')],
#               ['UTG', '', 134, ('Ts', '7h')],
#               ['LJ', '', 60, ('Ah', 'Jc')]],
#   'Stakes': (0.02, 0.05),
#   'WTSD': True,
#   'Winner': ['BU']},
#  {'Action': [['UTGf', 'LJf', 'HJf', 'BUr52', 'SBf', 'BBf']],
#   'Board': None,
#   'Players': [['UTG', '', 73, ('9h', '8s')],
#               ['LJ', '', 140, ('Ts', '2s')],
#               ['HJ', '', 111, ('Kd', '9d')],
#               ['BU', 'Hero', 52, ('Jh', 'Kc')],
#               ['SB', '', 177, ('Qd', '3d')],
#               ['BB', '', 114, ('Js', 'Qs')]],
#   'Stakes': (0.02, 0.05),
#   'WTSD': True,
#   'Winner': ['BU']},
#  {'Action': [['UTGr51', 'LJf', 'HJf', 'BUf', 'SBf', 'BBf']],
#   'Board': None,
#   'Players': [['BB', '', 85, ('4h', '8c')],
#               ['UTG', 'Hero', 51, ('Kd', 'Kh')],
#               ['LJ', '', 243, ('Js', 'Qd')],
#               ['HJ', '', 47, ('9d', '8s')],
#               ['BU', '', 191, ('8h', '7d')],
#               ['SB', '', 102, ('6h', '5h')]],
#   'Stakes': (0.02, 0.05),
#   'WTSD': True,
#   'Winner': ['UTG']},
#  {'Action': [['UTGf', 'LJf', 'HJr3', 'BUf', 'SBr51', 'BBc51', 'HJf']],
#   'Board': ['9h', '8s', '9c', '8c', '7h'],
#   'Players': [['UTG', '', 92, ('6c', '2d')],
#               ['LJ', '', 130, ('As', '2h')],
#               ['HJ', '', 116, ('Js', 'Kd')],
#               ['BU', '', 91, ('Qh', '8d')],
#               ['SB', 'Hero', 52, ('6d', 'Ad')],
#               ['BB', '', 158, ('Jd', 'Jh')]],
#   'Stakes': (0.02, 0.05),
#   'WTSD': True,
#   'Winner': ['BB', None]},
#  {'Action': [['UTGr49', 'LJf', 'HJf', 'BUf', 'SBf', 'BBf']],
#   'Board': None,
#   'Players': [['UTG', 'Hero', 49, ('Ad', '4d')],
#               ['LJ', '', 126, ('2c', '3d')],
#               ['HJ', '', 66, ('9d', '8d')],
#               ['BU', '', 129, ('Qc', '4s')],
#               ['SB', '', 542, ('Kh', '5h')],
#               ['BB', '', 73, ('Ks', '8h')]],
#   'Stakes': (0.02, 0.05),
#   'WTSD': True,
#   'Winner': ['UTG', None]},
#  {'Action': [['UTGf', 'LJc1', 'HJr50', 'BUf', 'SBf', 'BBf', 'LJf']],
#   'Board': None,
#   'Players': [['SB', '', 120, ('7s', 'Kh')],
#               ['BB', '', 81, ('3h', 'Ts')],
#               ['UTG', '', 380, ('5c', 'Qh')],
#               ['LJ', '', 113, ('6h', '5h')],
#               ['HJ', 'Hero', 50, ('Jd', 'Ah')],
#               ['BU', '', 44, ('9d', '6s')]],
#   'Stakes': (0.02, 0.05),
#   'WTSD': True,
#   'Winner': ['HJ', None]},
#  {'Action': [['UTGf', 'LJf', 'HJf', 'BUr53', 'SBf', 'BBf']],
#   'Board': None,
#   'Players': [['SB', '', 136, ('Th', '7h')],
#               ['BB', '', 92, ('Js', '6h')],
#               ['UTG', '', 49, ('2c', 'Qc')],
#               ['LJ', '', 224, ('9c', '4c')],
#               ['HJ', '', 99, ('3d', '9h')],
#               ['BU', 'Hero', 53, ('As', 'Kh')]],
#   'Stakes': (0.02, 0.05),
#   'WTSD': True,
#   'Winner': ['BU']},
#  {'Action': [['UTGr3',
#               'LJc3',
#               'HJr5',
#               'BUr55',
#               'SBf',
#               'BBf',
#               'UTGr98',
#               'LJf',
#               'HJc96']],
#   'Board': None,
#   'Players': [['SB', '', 93, ('9d', '5h')],
#               ['BB', '', 97, ('3s', '6s')],
#               ['UTG', '', 101, ('Td', 'Th')],
#               ['LJ', '', 126, ('6d', '6c')],
#               ['HJ', '', 111, ('Kh', 'Ad')],
#               ['BU', 'Hero', 55, ('Ac', 'Kc')]],
#   'Stakes': (0.02, 0.05),
#   'WTSD': True,
#   'Winner': ['BU']},
#  {'Action': [['UTGr49', 'LJf', 'HJf', 'BUf', 'SBf', 'BBf']],
#   'Board': None,
#   'Players': [['BU', '', 98, ('4d', '3c')],
#               ['SB', '', 90, ('Ad', '7s')],
#               ['BB', '', 124, ('7d', 'Qs')],
#               ['UTG', 'Hero', 49, ('Jh', 'Kh')],
#               ['LJ', '', 169, ('8c', 'Ts')],
#               ['HJ', '', 49, ('8s', 'As')]],
#   'Stakes': (0.02, 0.05),
#   'WTSD': True,
#   'Winner': ['UTG']},
#  {'Action': [['UTGr2', 'LJf', 'HJf', 'BUf', 'SBr47', 'BBf', 'UTGf']],
#   'Board': None,
#   'Players': [['UTG', '', 50, ('Kh', 'Js')],
#               ['LJ', '', 49, ('Jh', '3h')],
#               ['HJ', '', 504, ('5d', '2s')],
#               ['BU', '', 100, ('6d', '3d')],
#               ['SB', 'Hero', 47, ('4c', '4s')],
#               ['BB', '', 145, ('9s', '9h')]],
#   'Stakes': (0.02, 0.05),
#   'WTSD': True,
#   'Winner': ['SB', None]},
#  {'Action': [['UTGr47', 'LJf', 'HJf', 'BUf', 'SBf', 'BBf']],
#   'Board': None,
#   'Players': [['BB', '', 97, ('Td', '3s')],
#               ['UTG', 'Hero', 47, ('Ac', 'Kd')],
#               ['LJ', '', 127, ('2c', '3c')],
#               ['HJ', '', 485, ('Qs', '9d')],
#               ['BU', '', 158, ('7c', 'Ah')],
#               ['SB', '', 103, ('2d', 'Th')]],
#   'Stakes': (0.02, 0.05),
#   'WTSD': True,
#   'Winner': ['UTG', None]},
#  {'Action': [['UTGf', 'LJf', 'HJf', 'BUf', 'SBr46', 'BBf']],
#   'Board': None,
#   'Players': [['UTG', '', 1, ('7h', 'Td')],
#               ['LJ', '', 18, ('3d', 'Kh')],
#               ['HJ', '', 94, ('2s', 'Jc')],
#               ['BU', '', 159, ('9d', '5s')],
#               ['SB', 'Hero', 46, ('Qc', 'Qs')],
#               ['BB', '', 193, ('9s', '6h')]],
#   'Stakes': (0.02, 0.05),
#   'WTSD': True,
#   'Winner': ['SB']},
#  {'Action': [['UTGf', 'LJc1', 'HJr4', 'BUr47', 'SBf', 'BBf', 'LJc46', 'HJf']],
#   'Board': None,
#   'Players': [['BU', 'Hero', 47, ('As', '4s')],
#               ['SB', '', 126, ('8d', '4h')],
#               ['BB', '', 104, ('Ad', 'Td')],
#               ['UTG', '', 60, ('7c', 'Jh')],
#               ['LJ', '', 143, ('Kd', 'Ks')],
#               ['HJ', '', 350, ('Kc', '9c')]],
#   'Stakes': (0.02, 0.05),
#   'WTSD': True,
#   'Winner': ['BU']},
#  {'Action': [['UTGf', 'LJf', 'HJf', 'BUf', 'SBr50', 'BBf']],
#   'Board': None,
#   'Players': [['BB', '', 364, ('3h', 'Ts')],
#               ['UTG', '', 46, ('9s', '3c')],
#               ['LJ', '', 51, ('Jc', '9d')],
#               ['HJ', '', 320, ('2d', '5s')],
#               ['BU', '', 75, ('5c', 'Jd')],
#               ['SB', 'Hero', 50, ('Ks', 'Jh')]],
#   'Stakes': (0.02, 0.05),
#   'WTSD': True,
#   'Winner': ['SB', None]},
#  {'Action': [['UTGf', 'LJr2', 'HJr49', 'BUf', 'SBf', 'BBf', 'LJf']],
#   'Board': None,
#   'Players': [['UTG', '', 112, ('3c', 'Jd')],
#               ['LJ', '', 113, ('8c', 'Ac')],
#               ['HJ', 'Hero', 49, ('As', 'Qh')],
#               ['BU', '', 143, ('9c', '7d')],
#               ['SB', '', 113, ('7h', '6s')],
#               ['BB', '', 48, ('5c', 'Ts')]],
#   'Stakes': (0.02, 0.05),
#   'WTSD': True,
#   'Winner': ['HJ']},
#  {'Action': [['UTGf', 'LJf', 'HJf', 'BUf', 'SBr52', 'BBf']],
#   'Board': None,
#   'Players': [['SB', 'Hero', 52, ('8c', '8h')],
#               ['BB', '', 243, ('Td', '6d')],
#               ['UTG', '', 120, ('7c', '4c')],
#               ['LJ', '', 103, ('2d', '6h')],
#               ['HJ', '', 140, ('Qd', '9c')],
#               ['BU', '', 47, ('5c', '3s')]],
#   'Stakes': (0.02, 0.05),
#   'WTSD': True,
#   'Winner': ['SB', None]},
#  {'Action': [['UTGr53', 'LJf', 'HJf', 'BUf', 'SBf', 'BBf']],
#   'Board': None,
#   'Players': [['SB', '', 46, ('4s', 'Js')],
#               ['BB', '', 129, ('7c', '8s')],
#               ['UTG', 'Hero', 53, ('Ah', 'Qd')],
#               ['LJ', '', 623, ('4d', 'Ks')],
#               ['HJ', '', 131, ('8d', '6d')],
#               ['BU', '', 113, ('Tc', 'Qs')]],
#   'Stakes': (0.02, 0.05),
#   'WTSD': True,
#   'Winner': ['UTG']},
#  {'Action': [['UTGf', 'LJf', 'HJf', 'BUr48', 'SBf', 'BBf']],
#   'Board': None,
#   'Players': [['SB', '', 94, ('4c', '8s')],
#               ['BB', '', 45, ('9h', '3h')],
#               ['UTG', '', 52, ('2h', 'Qh')],
#               ['LJ', '', 113, ('7s', 'Td')],
#               ['HJ', '', 127, ('Ks', '6s')],
#               ['BU', 'Hero', 48, ('Ad', '5d')]],
#   'Stakes': (0.02, 0.05),
#   'WTSD': True,
#   'Winner': [None, 'BU']},
#  {'Action': [['UTGf', 'LJr2', 'HJf', 'BUf', 'SBc2', 'BBr48', 'LJf', 'SBf']],
#   'Board': None,
#   'Players': [['BU', '', 110, ('Ts', '3c')],
#               ['SB', '', 101, ('7h', 'Kh')],
#               ['BB', 'Hero', 49, ('8s', '8d')],
#               ['UTG', '', 382, ('Tc', '6h')],
#               ['LJ', '', 84, ('Ks', 'Jc')],
#               ['HJ', '', 538, ('2c', '4c')]],
#   'Stakes': (0.02, 0.05),
#   'WTSD': True,
#   'Winner': ['BB']},
#  {'Action': [['UTGf', 'LJr2', 'HJc2', 'BUr54', 'SBf', 'BBf', 'LJf', 'HJf']],
#   'Board': None,
#   'Players': [['SB', '', 141, ('2h', '2d')],
#               ['BB', '', 125, ('8h', 'Tc')],
#               ['UTG', '', 95, ('9s', 'Td')],
#               ['LJ', '', 62, ('9c', 'Kd')],
#               ['HJ', '', 46, ('4h', '4s')],
#               ['BU', 'Hero', 54, ('As', 'Qh')]],
#   'Stakes': (0.02, 0.05),
#   'WTSD': True,
#   'Winner': ['BU']},
#  {'Action': [['UTGr2', 'LJf', 'HJr58', 'BUf', 'SBf', 'BBf', 'UTGc56']],
#   'Board': None,
#   'Players': [['HJ', 'Hero', 58, ('9d', '9c')],
#               ['BU', '', 36, ('Kc', 'Td')],
#               ['SB', '', 559, ('Qs', '2s')],
#               ['BB', '', 43, ('4d', '8h')],
#               ['UTG', '', 104, ('Ah', 'As')],
#               ['LJ', '', 107, ('2c', '3s')]],
#   'Stakes': (0.02, 0.05),
#   'WTSD': True,
#   'Winner': ['UTG']},
#  {'Action': [['UTGf',
#               'LJr2',
#               'HJc2',
#               'BUc2',
#               'SBf',
#               'BBr50',
#               'LJf',
#               'HJf',
#               'BUf']],
#   'Board': None,
#   'Players': [['HJ', '', 102, ('Ac', '4d')],
#               ['BU', '', 124, ('9h', 'Th')],
#               ['SB', '', 145, ('3s', 'Qs')],
#               ['BB', 'Hero', 51, ('Qd', 'Ah')],
#               ['UTG', '', 87, ('9c', '8h')],
#               ['LJ', '', 218, ('6h', '6s')]],
#   'Stakes': (0.02, 0.05),
#   'WTSD': True,
#   'Winner': ['BB', 'BB']},
#  {'Action': [['UTGr3', 'LJf', 'HJc3', 'BUf', 'SBr44', 'BBf', 'UTGr46', 'HJf']],
#   'Board': None,
#   'Players': [['LJ', '', 130, ('5d', 'Th')],
#               ['HJ', '', 551, ('Td', '9s')],
#               ['BU', '', 135, ('As', '3c')],
#               ['SB', 'Hero', 44, ('Ts', 'Ks')],
#               ['BB', '', 100, ('9d', '6c')],
#               ['UTG', '', 49, ('Ad', 'Kc')]],
#   'Stakes': (0.02, 0.05),
#   'WTSD': True,
#   'Winner': ['UTG']},
#  {'Action': [['UTGf', 'LJf', 'HJr3', 'BUr9', 'SBf', 'BBr50', 'HJf', 'BUc42']],
#   'Board': None,
#   'Players': [['HJ', '', 123, ('Kh', 'Jh')],
#               ['BU', '', 352, ('6s', 'As')],
#               ['SB', '', 32, ('Th', 'Jd')],
#               ['BB', 'Hero', 51, ('Js', 'Ac')],
#               ['UTG', '', 139, ('8s', 'Td')],
#               ['LJ', '', 614, ('Qd', '2d')]],
#   'Stakes': (0.02, 0.05),
#   'WTSD': True,
#   'Winner': [None, 'BB']},
#  {'Action': [['UTGf', 'LJr48', 'HJf', 'BUf', 'SBf', 'BBf']],
#   'Board': None,
#   'Players': [['BB', '', 31, ('5d', 'Js')],
#               ['UTG', '', 51, ('3d', '7s')],
#               ['LJ', 'Hero', 48, ('Ad', 'Ah')],
#               ['HJ', '', 98, ('Ac', '7d')],
#               ['BU', '', 80, ('4s', '2h')],
#               ['SB', '', 87, ('5h', 'Kc')]],
#   'Stakes': (0.02, 0.05),
#   'WTSD': True,
#   'Winner': ['LJ', None]},
#  {'Action': [['UTGf', 'LJr48', 'HJf', 'BUf', 'SBf', 'BBf']],
#   'Board': None,
#   'Players': [['LJ', 'Hero', 48, ('7h', 'Ah')],
#               ['HJ', '', 92, ('5c', '5h')],
#               ['BU', '', 177, ('6h', '8c')],
#               ['SB', '', 44, ('Td', '4d')],
#               ['BB', '', 615, ('2s', 'Qd')],
#               ['UTG', '', 84, ('8h', 'Ac')]],
#   'Stakes': (0.02, 0.05),
#   'WTSD': True,
#   'Winner': ['LJ']},
#  {'Action': [['UTGr48', 'LJf', 'HJf', 'BUf', 'SBf', 'BBf']],
#   'Board': None,
#   'Players': [['HJ', '', 614, ('Qs', '5c')],
#               ['BU', '', 97, ('4d', '7h')],
#               ['SB', '', 40, ('Kc', '9s')],
#               ['BB', '', 124, ('2h', '9c')],
#               ['UTG', 'Hero', 48, ('8h', '8d')],
#               ['LJ', '', 123, ('Tc', 'Jh')]],
#   'Stakes': (0.02, 0.05),
#   'WTSD': True,
#   'Winner': ['UTG', None]},
#  {'Action': [['UTGf', 'LJf', 'HJf', 'BUf', 'SBc1', 'BBr48', 'SBc48']],
#   'Board': None,
#   'Players': [['BB', 'Hero', 49, ('Qs', 'Ah')],
#               ['UTG', '', 31, ('4s', 'Td')],
#               ['LJ', '', 74, ('6c', 'Qd')],
#               ['HJ', '', 142, ('7c', 'As')],
#               ['BU', '', 612, ('3c', '6d')],
#               ['SB', '', 99, ('Ac', 'Kc')]],
#   'Stakes': (0.02, 0.05),
#   'WTSD': True,
#   'Winner': ['SB']},
#  {'Action': [['UTGf', 'LJf', 'HJf', 'BUr3', 'SBf', 'BBr50', 'BUf']],
#   'Board': None,
#   'Players': [['UTG', '', 96, ('4c', 'Jd')],
#               ['LJ', '', 122, ('5h', 'Ah')],
#               ['HJ', '', 22, ('Ac', '9h')],
#               ['BU', '', 120, ('2h', '2d')],
#               ['SB', '', 124, ('Th', 'Qc')],
#               ['BB', 'Hero', 51, ('Js', 'Jc')]],
#   'Stakes': (0.02, 0.05),
#   'WTSD': True,
#   'Winner': ['BB', None]},
#  {'Action': [['UTGf', 'LJf', 'HJr3', 'BUr53', 'SBf', 'BBf', 'HJf']],
#   'Board': None,
#   'Players': [['HJ', '', 95, ('4h', 'As')],
#               ['BU', 'Hero', 53, ('Jd', 'Jc')],
#               ['SB', '', 203, ('Qh', '6s')],
#               ['BB', '', 90, ('Ks', 'Jh')],
#               ['UTG', '', 108, ('8h', '5c')],
#               ['LJ', '', 85, ('Kh', '8d')]],
#   'Stakes': (0.02, 0.05),
#   'WTSD': True,
#   'Winner': ['BU']},
#  {'Action': [['UTGf', 'LJr2', 'HJf', 'BUc2', 'SBf', 'BBr50', 'LJf', 'BUf']],
#   'Board': None,
#   'Players': [['BU', '', 113, ('Ah', 'Tc')],
#               ['SB', '', 96, ('7d', '3c')],
#               ['BB', 'Hero', 51, ('Qc', 'Kd')],
#               ['UTG', '', 44, ('Ks', '9d')],
#               ['LJ', '', 206, ('7s', '7c')],
#               ['HJ', '', 94, ('5h', '9s')]],
#   'Stakes': (0.02, 0.05),
#   'WTSD': True,
#   'Winner': ['BB', None]},
#  {'Action': [['UTGf', 'LJf', 'HJf', 'BUf', 'SBr47', 'BBf']],
#   'Board': None,
#   'Players': [['SB', 'Hero', 47, ('Ks', 'Js')],
#               ['BB', '', 141, ('9c', '8h')],
#               ['UTG', '', 136, ('Ts', '7d')],
#               ['LJ', '', 139, ('Jc', '4c')],
#               ['HJ', '', 35, ('6d', '5h')],
#               ['BU', '', 97, ('6h', 'Qc')]],
#   'Stakes': (0.02, 0.05),
#   'WTSD': True,
#   'Winner': ['SB']},
#  {'Action': [['UTGr48', 'LJf', 'HJf', 'BUf', 'SBf', 'BBf']],
#   'Board': None,
#   'Players': [['BB', '', 97, ('5h', '3c')],
#               ['UTG', 'Hero', 48, ('9c', '9s')],
#               ['LJ', '', 99, ('5d', 'Kd')],
#               ['HJ', '', 35, ('7d', 'As')],
#               ['BU', '', 112, ('Ac', 'Qs')],
#               ['SB', '', 99, ('7h', '2s')]],
#   'Stakes': (0.02, 0.05),
#   'WTSD': True,
#   'Winner': ['UTG', None]},
#  {'Action': [['UTGf', 'LJf', 'HJr3', 'BUc3', 'SBf', 'BBr49', 'HJc46', 'BUf']],
#   'Board': None,
#   'Players': [['SB', '', 99, ('5h', 'Qh')],
#               ['BB', 'Hero', 50, ('8s', '8d')],
#               ['UTG', '', 96, ('2c', 'Tc')],
#               ['LJ', '', 139, ('4d', 'Kc')],
#               ['HJ', '', 77, ('Ah', 'Qd')],
#               ['BU', '', 119, ('9s', '9h')]],
#   'Stakes': (0.02, 0.05),
#   'WTSD': True,
#   'Winner': ['BB']},
#  {'Action': [['UTGf', 'LJf', 'HJf', 'BUf', 'SBr50', 'BBf']],
#   'Board': None,
#   'Players': [['SB', 'Hero', 50, ('Kc', 'Ks')],
#               ['BB', '', 174, ('Td', '3d')],
#               ['UTG', '', 101, ('9s', '7s')],
#               ['LJ', '', 113, ('Ts', '2c')],
#               ['HJ', '', 119, ('4d', '7h')],
#               ['BU', '', 720, ('3s', 'Js')]],
#   'Stakes': (0.02, 0.05),
#   'WTSD': True,
#   'Winner': ['SB']},
#  {'Action': [['UTGf', 'LJf', 'HJr49', 'BUf', 'SBf', 'BBf']],
#   'Board': None,
#   'Players': [['HJ', 'Hero', 49, ('Ks', 'Ah')],
#               ['BU', '', 219, ('8h', '3d')],
#               ['SB', '', 116, ('2d', '5s')],
#               ['BB', '', 107, ('3s', '4c')],
#               ['UTG', '', 82, ('Qc', '7d')],
#               ['LJ', '', 158, ('9c', '2c')]],
#   'Stakes': (0.02, 0.05),
#   'WTSD': True,
#   'Winner': ['HJ']},
#  {'Action': [['UTGc1', 'LJf', 'HJf', 'BUf', 'SBc1', 'BBr48', 'UTGf', 'SBf']],
#   'Board': None,
#   'Players': [['BB', 'Hero', 49, ('Jh', 'Qh')],
#               ['UTG', '', 101, ('5d', '5c')],
#               ['LJ', '', 96, ('4d', '6h')],
#               ['HJ', '', 94, ('4c', '8h')],
#               ['BU', '', 155, ('2h', '6c')],
#               ['SB', '', 120, ('5h', '7h')]],
#   'Stakes': (0.02, 0.05),
#   'WTSD': True,
#   'Winner': ['BB', None]},
#  {'Action': [['UTGr49', 'LJf', 'HJf', 'BUf', 'SBf', 'BBf']],
#   'Board': None,
#   'Players': [['UTG', 'Hero', 49, ('Jh', 'Jc')],
#               ['LJ', '', 82, ('Td', '3s')],
#               ['HJ', '', 121, ('2h', 'Ts')],
#               ['BU', '', 109, ('4d', '3h')],
#               ['SB', '', 107, ('9d', '5s')],
#               ['BB', '', 155, ('3c', 'Ks')]],
#   'Stakes': (0.02, 0.05),
#   'WTSD': True,
#   'Winner': ['UTG']},
#  {'Action': [['UTGf', 'LJr53', 'HJf', 'BUr81', 'SBf', 'BBf']],
#   'Board': None,
#   'Players': [['LJ', 'Hero', 53, ('Kh', 'Qs')],
#               ['HJ', '', 142, ('5c', '9d')],
#               ['BU', '', 81, ('6d', '6c')],
#               ['SB', '', 146, ('4d', '7s')],
#               ['BB', '', 108, ('4s', '3h')],
#               ['UTG', '', 88, ('4c', '3d')]],
#   'Stakes': (0.02, 0.05),
#   'WTSD': True,
#   'Winner': ['LJ']},
#  {'Action': [['UTGf', 'LJf', 'HJr3', 'BUr48', 'SBf', 'BBf', 'HJf']],
#   'Board': None,
#   'Players': [['LJ', '', 50, ('Jd', 'Kd')],
#               ['HJ', '', 191, ('Jc', 'Td')],
#               ['BU', 'Hero', 48, ('Kh', 'Ad')],
#               ['SB', '', 99, ('7s', 'Ks')],
#               ['BB', '', 120, ('6s', '5c')],
#               ['UTG', '', 100, ('5s', '2c')]],
#   'Stakes': (0.02, 0.05),
#   'WTSD': True,
#   'Winner': ['BU']},
#  {'Action': [['UTGc1', 'LJf', 'HJf', 'BUr45', 'SBc44', 'BBf', 'UTGf']],
#   'Board': None,
#   'Players': [['SB', '', 79, ('Jh', 'Ks')],
#               ['BB', '', 123, ('8s', '4c')],
#               ['UTG', '', 88, ('8d', 'Js')],
#               ['LJ', '', 146, ('Qh', '9c')],
#               ['HJ', '', 70, ('3c', '7s')],
#               ['BU', 'Hero', 45, ('Th', 'Ad')]],
#   'Stakes': (0.02, 0.05),
#   'WTSD': True,
#   'Winner': ['BU']},
#  {'Action': [['UTGr50', 'LJf', 'HJf', 'BUf', 'SBf', 'BBf']],
#   'Board': None,
#   'Players': [['UTG', 'Hero', 50, ('As', 'Kd')],
#               ['LJ', '', 98, ('7h', 'Th')],
#               ['HJ', '', 225, ('9h', '2c')],
#               ['BU', '', 110, ('Kh', '6d')],
#               ['SB', '', 49, ('7c', '4s')],
#               ['BB', '', 290, ('6s', '4c')]],
#   'Stakes': (0.02, 0.05),
#   'WTSD': True,
#   'Winner': ['UTG', None]},
#  {'Action': [['UTGr50', 'LJf', 'HJf', 'BUr732', 'SBf', 'BBf']],
#   'Board': ['7d', '8s', '3h', 'Qh', 'As'],
#   'Players': [['BB', '', 129, ('Ts', 'Jd')],
#               ['UTG', 'Hero', 50, ('Ks', 'Qs')],
#               ['LJ', '', 99, ('6c', '4s')],
#               ['HJ', '', 155, ('Jh', '4c')],
#               ['BU', '', 732, ('Kd', 'Ah')],
#               ['SB', '', 30, ('Ad', '2c')]],
#   'Stakes': (0.02, 0.05),
#   'WTSD': True,
#   'Winner': ['BU', None]},
#  {'Action': [['UTGr3', 'LJf', 'HJf', 'BUf', 'SBr48', 'BBf', 'UTGc46']],
#   'Board': None,
#   'Players': [['LJ', '', 97, ('5h', '7c')],
#               ['HJ', '', 102, ('Tc', '7s')],
#               ['BU', '', 147, ('6h', '4c')],
#               ['SB', 'Hero', 49, ('Js', 'Qs')],
#               ['BB', '', 50, ('Ah', '2s')],
#               ['UTG', '', 274, ('As', 'Ks')]],
#   'Stakes': (0.02, 0.05),
#   'WTSD': True,
#   'Winner': ['UTG']},
#  {'Action': [['UTGf', 'LJf', 'HJf', 'BUc1', 'SBr50', 'BBf', 'BUf']],
#   'Board': None,
#   'Players': [['SB', 'Hero', 50, ('Qc', 'Qd')],
#               ['BB', '', 319, ('As', '9d')],
#               ['UTG', '', 499, ('7s', '2s')],
#               ['LJ', '', 147, ('5d', '8h')],
#               ['HJ', '', 115, ('2d', 'Ah')],
#               ['BU', '', 157, ('Jd', 'Ac')]],
#   'Stakes': (0.02, 0.05),
#   'WTSD': True,
#   'Winner': ['SB', None]},
#  {'Action': [['UTGf', 'LJr51', 'HJr101', 'BUf', 'SBf', 'BBr119', 'HJc19']],
#   'Board': None,
#   'Players': [['LJ', 'Hero', 51, ('7d', 'Ad')],
#               ['HJ', '', 146, ('Jh', 'Jd')],
#               ['BU', '', 94, ('7h', '6h')],
#               ['SB', '', 168, ('3d', 'Js')],
# ...
#               ['HJ', '', 97, ('4c', '7c')],
#               ['BU', '', 85, ('6c', '7s')],
#               ['SB', '', 71, ('Ts', '9d')],
#               ['BB', '', 215, ('7d', 'Qd')]],
#   'Stakes': (0.02, 0.05),
#   'WTSD': True,
#   'Winner': ['LJ', None]},
#  {'Action': [['UTGf', 'LJr20', 'HJf', 'BUc20', 'SBf', 'BBr47', 'BUc28']],
#   'Board': None,
#   'Players': [['BU', '', 298, ('Kc', 'Tc')],
#               ['SB', '', 143, ('5c', 'As')],
#               ['BB', 'Hero', 48, ('Kh', 'Qd')],
#               ['UTG', '', 114, ('2d', '9h')],
#               ['LJ', '', 20, ('Ad', 'Td')],
#               ['HJ', '', 109, ('2s', 'Ac')]],
#   'Stakes': (0.02, 0.05),
#   'WTSD': True,
#   'Winner': ['LJ']},
#  {'Action': [['UTGr53', 'LJf', 'HJr60', 'BUf', 'SBf', 'BBf']],
#   'Board': None,
#   'Players': [['SB', '', 535, ('Th', 'Tc')],
#               ['BB', '', 251, ('5d', '6s')],
#               ['UTG', 'Hero', 53, ('Ks', 'Js')],
#               ['LJ', '', 57, ('7s', 'Ad')],
#               ['HJ', '', 60, ('Ah', 'Jc')],
#               ['BU', '', 83, ('3d', '9d')]],
#   'Stakes': (0.02, 0.05),
#   'WTSD': True,
#   'Winner': ['UTG']},
#  {'Action': [['UTGf', 'LJf', 'HJf', 'BUr3', 'SBr47', 'BBf', 'BUf']],
#   'Board': None,
#   'Players': [['BU', '', 96, ('6h', 'Ad')],
#               ['SB', 'Hero', 47, ('4s', '4c')],
#               ['BB', '', 182, ('6c', 'Kd')],
#               ['UTG', '', 288, ('Tc', '3d')],
#               ['LJ', '', 298, ('8h', '3h')],
#               ['HJ', '', 419, ('Qd', '7s')]],
#   'Stakes': (0.02, 0.05),
#   'WTSD': True,
#   'Winner': ['SB']},
#  {'Action': [['UTGf', 'LJf', 'HJf', 'BUr50', 'SBf', 'BBf']],
#   'Board': None,
#   'Players': [['BU', 'Hero', 50, ('Kc', 'Tc')],
#               ['SB', '', 37, ('3s', '5h')],
#               ['BB', '', 142, ('Ks', '4s')],
#               ['UTG', '', 100, ('Jh', '8c')],
#               ['LJ', '', 535, ('As', 'Th')],
#               ['HJ', '', 287, ('Qs', '7h')]],
#   'Stakes': (0.02, 0.05),
#   'WTSD': True,
#   'Winner': ['BU', None]},
#  {'Action': [['UTGf', 'LJf', 'HJr3', 'BUf', 'SBf', 'BBr48', 'HJf']],
#   'Board': None,
#   'Players': [['BB', 'Hero', 49, ('8h', '8c')],
#               ['UTG', '', 90, ('9s', 'Kh')],
#               ['LJ', '', 88, ('3h', 'Ac')],
#               ['HJ', '', 132, ('Jc', 'Tc')],
#               ['BU', '', 100, ('6h', '4s')],
#               ['SB', '', 541, ('Td', '5c')]],
#   'Stakes': (0.02, 0.05),
#   'WTSD': True,
#   'Winner': ['BB', None]},
#  {'Action': [['UTGr52', 'LJf', 'HJf', 'BUf', 'SBf', 'BBf']],
#   'Board': None,
#   'Players': [['UTG', 'Hero', 52, ('7c', '7d')],
#               ['LJ', '', 100, ('Ts', '3s')],
#               ['HJ', '', 110, ('5h', '5d')],
#               ['BU', '', 130, ('Js', '7h')],
#               ['SB', '', 82, ('Jh', 'Jd')],
#               ['BB', '', 446, ('4s', 'Ks')]],
#   'Stakes': (0.02, 0.05),
#   'WTSD': True,
#   'Winner': ['UTG']},
#  {'Action': [['UTGr2', 'LJf', 'HJr52', 'BUf', 'SBf', 'BBf', 'UTGc50']],
#   'Board': ['Tc', '7h', '3h', 'As', 'Qh'],
#   'Players': [['BB', '', 445, ('Jc', '5d')],
#               ['UTG', '', 179, ('4s', '4h')],
#               ['LJ', '', 117, ('6s', 'Jd')],
#               ['HJ', 'Hero', 52, ('Qd', 'Qs')],
#               ['BU', '', 122, ('4c', 'Ac')],
#               ['SB', '', 150, ('7d', '5c')]],
#   'Stakes': (0.02, 0.05),
#   'WTSD': True,
#   'Winner': ['HJ', None]},
#  {'Action': [['UTGf', 'LJr2', 'HJf', 'BUf', 'SBf', 'BBr49', 'LJf']],
#   'Board': None,
#   'Players': [['BB', 'Hero', 50, ('Qh', 'Kd')],
#               ['UTG', '', 91, ('4c', 'Qc')],
#               ['LJ', '', 191, ('Qd', '9d')],
#               ['HJ', '', 100, ('9s', 'Ac')],
#               ['BU', '', 62, ('8d', '9h')],
#               ['SB', '', 93, ('5d', '4h')]],
#   'Stakes': (0.02, 0.05),
#   'WTSD': True,
#   'Winner': ['UTG', 'BB']},
#  {'Action': [['UTGr3', 'LJf', 'HJr50', 'BUf', 'SBf', 'BBf', 'UTGf']],
#   'Board': None,
#   'Players': [['HJ', 'Hero', 50, ('Qh', 'Ad')],
#               ['BU', '', 60, ('6s', '2d')],
#               ['SB', '', 116, ('7c', '3s')],
#               ['BB', '', 155, ('4s', '6h')],
#               ['UTG', '', 296, ('Kh', 'Jh')],
#               ['LJ', '', 108, ('Kd', '5h')]],
#   'Stakes': (0.02, 0.05),
#   'WTSD': True,
#   'Winner': ['HJ']},
#  {'Action': [['UTGr54', 'LJf', 'HJf', 'BUr95', 'SBf', 'BBf']],
#   'Board': None,
#   'Players': [['UTG', 'Hero', 54, ('Jd', 'Jc')],
#               ['LJ', '', 538, ('9s', '5s')],
#               ['HJ', '', 112, ('As', '7d')],
#               ['BU', '', 95, ('Qd', 'Qh')],
#               ['SB', '', 100, ('Qc', 'Ad')],
#               ['BB', '', 292, ('3c', 'Td')]],
#   'Stakes': (0.02, 0.05),
#   'WTSD': True,
#   'Winner': ['UTG']},
#  {'Action': [['UTGr3', 'LJf', 'HJf', 'BUf', 'SBf', 'BBr49', 'UTGc47']],
#   'Board': None,
#   'Players': [['HJ', '', 538, ('Ah', '7d')],
#               ['BU', '', 179, ('7s', 'Th')],
#               ['SB', '', 53, ('Tc', '2s')],
#               ['BB', 'Hero', 50, ('Ts', 'As')],
#               ['UTG', '', 107, ('Qd', 'Qs')],
#               ['LJ', '', 118, ('4h', '3s')]],
#   'Stakes': (0.02, 0.05),
#   'WTSD': True,
#   'Winner': ['UTG']},
#  {'Action': [['UTGf', 'LJf', 'HJr3', 'BUr50', 'SBf', 'BBf', 'HJf']],
#   'Board': None,
#   'Players': [['BU', 'Hero', 50, ('Ad', '4d')],
#               ['SB', '', 126, ('5h', 'Kh')],
#               ['BB', '', 115, ('8d', '3s')],
#               ['UTG', '', 81, ('3h', 'Tc')],
#               ['LJ', '', 106, ('4s', '9s')],
#               ['HJ', '', 112, ('Th', 'Ac')]],
#   'Stakes': (0.02, 0.05),
#   'WTSD': True,
#   'Winner': ['BU']},
#  {'Action': [['UTGf', 'LJf', 'HJr53', 'BUf', 'SBf', 'BBf']],
#   'Board': None,
#   'Players': [['BB', '', 122, ('8s', '7h')],
#               ['UTG', '', 37, ('Ks', '8c')],
#               ['LJ', '', 536, ('Ah', '7c')],
#               ['HJ', 'Hero', 53, ('6s', '6h')],
#               ['BU', '', 158, ('2s', 'Tc')],
#               ['SB', '', 106, ('5s', 'Kc')]],
#   'Stakes': (0.02, 0.05),
#   'WTSD': True,
#   'Winner': ['HJ']},
#  {'Action': [['UTGf', 'LJf', 'HJf', 'BUr53', 'SBf', 'BBb36']],
#   'Board': ['4d', '8d', 'Tc', '5c', '6c'],
#   'Players': [['BU', 'Hero', 53, ('As', 'Ts')],
#               ['SB', '', 121, ('3c', 'Th')],
#               ['BB', '', 37, ('8c', 'Ad')],
#               ['UTG', '', 93, ('Qh', 'Td')],
#               ['LJ', '', 100, ('9s', '7h')],
#               ['HJ', '', 54, ('6d', '7s')]],
#   'Stakes': (0.02, 0.05),
#   'WTSD': True,
#   'Winner': ['BU', None]},
#  {'Action': [['UTGr3', 'LJf', 'HJf', 'BUr47', 'SBf', 'BBf', 'UTGc44']],
#   'Board': None,
#   'Players': [['BU', 'Hero', 47, ('9s', '9d')],
#               ['SB', '', 109, ('3d', 'Ts')],
#               ['BB', '', 104, ('8s', '2s')],
#               ['UTG', '', 114, ('Jd', 'Js')],
#               ['LJ', '', 113, ('7c', '8h')],
#               ['HJ', '', 125, ('9h', 'Td')]],
#   'Stakes': (0.02, 0.05),
#   'WTSD': True,
#   'Winner': ['UTG']},
#  {'Action': [['UTGr50', 'LJf', 'HJf', 'BUf', 'SBf', 'BBf']],
#   'Board': None,
#   'Players': [['BB', '', 79, ('6c', '4c')],
#               ['UTG', 'Hero', 50, ('5h', '5d')],
#               ['LJ', '', 161, ('5s', 'Ad')],
#               ['HJ', '', 77, ('Ks', '7s')],
#               ['BU', '', 99, ('7h', '6d')],
#               ['SB', '', 115, ('5c', 'Qc')]],
#   'Stakes': (0.02, 0.05),
#   'WTSD': True,
#   'Winner': ['UTG', None]},
#  {'Action': [['UTGf', 'LJf', 'HJr2', 'BUf', 'SBr50', 'BBf', 'HJf']],
#   'Board': None,
#   'Players': [['BU', '', 160, ('9c', '2s')],
#               ['SB', 'Hero', 50, ('Jc', 'Qc')],
#               ['BB', '', 98, ('8s', '9s')],
#               ['UTG', '', 100, ('Jd', '5c')],
#               ['LJ', '', 204, ('Js', '4s')],
#               ['HJ', '', 131, ('8h', 'Th')]],
#   'Stakes': (0.02, 0.05),
#   'WTSD': True,
#   'Winner': ['SB', None]},
#  {'Action': [['UTGf', 'LJf', 'HJf', 'BUr2', 'SBr53', 'BBf', 'BUf']],
#   'Board': None,
#   'Players': [['LJ', '', 112, ('Ad', '2c')],
#               ['HJ', '', 125, ('7d', '8s')],
#               ['BU', '', 103, ('9h', 'Ah')],
#               ['SB', 'Hero', 53, ('As', 'Td')],
#               ['BB', '', 186, ('3d', '5s')],
#               ['UTG', '', 240, ('Qs', '7s')]],
#   'Stakes': (0.02, 0.05),
#   'WTSD': True,
#   'Winner': ['SB']},
#  {'Action': [['UTGf', 'LJf', 'HJf', 'BUr49', 'SBf', 'BBf']],
#   'Board': None,
#   'Players': [['BU', 'Hero', 49, ('As', 'Jd')],
#               ['SB', '', 106, ('3d', '8c')],
#               ['BB', '', 160, ('4c', 'Ks')],
#               ['UTG', '', 78, ('Jc', '6h')],
#               ['LJ', '', 108, ('8d', 'Tc')],
#               ['HJ', '', 122, ('Ts', 'Ad')]],
#   'Stakes': (0.02, 0.05),
#   'WTSD': True,
#   'Winner': [None, 'BU']},
#  {'Action': [['UTGr46', 'LJf', 'HJf', 'BUf', 'SBf', 'BBf']],
#   'Board': None,
#   'Players': [['BU', '', 151, ('5d', '3d')],
#               ['SB', '', 166, ('Jh', '4h')],
#               ['BB', '', 57, ('9d', 'Ts')],
#               ['UTG', 'Hero', 46, ('Td', 'Ac')],
#               ['LJ', '', 124, ('5h', '8c')],
#               ['HJ', '', 98, ('4c', 'Qd')]],
#   'Stakes': (0.02, 0.05),
#   'WTSD': True,
#   'Winner': ['UTG', None]},
#  {'Action': [['UTGr3', 'LJr46', 'HJf', 'BUf', 'SBf', 'BBf', 'UTGf']],
#   'Board': None,
#   'Players': [['SB', '', 142, ('7d', '9d')],
#               ['BB', '', 77, ('2d', '5s')],
#               ['UTG', '', 203, ('8d', 'Ad')],
#               ['LJ', 'Hero', 46, ('Ks', 'Kd')],
#               ['HJ', '', 525, ('5d', '3c')],
#               ['BU', '', 100, ('Kc', 'Tc')]],
#   'Stakes': (0.02, 0.05),
#   'WTSD': True,
#   'Winner': ['BU', 'LJ']},
#  {'Action': [['UTGf', 'LJf', 'HJf', 'BUf', 'SBr49', 'BBf']],
#   'Board': None,
#   'Players': [['BU', '', 99, ('6s', 'Kh')],
#               ['SB', 'Hero', 49, ('7d', '7s')],
#               ['BB', '', 139, ('5h', '8h')],
#               ['UTG', '', 185, ('Td', '4c')],
#               ['LJ', '', 99, ('5d', 'Qs')],
#               ['HJ', '', 82, ('4s', '2c')]],
#   'Stakes': (0.02, 0.05),
#   'WTSD': True,
#   'Winner': ['SB']},
#  {'Action': [['UTGf', 'LJf', 'HJf', 'BUr3', 'SBf', 'BBr49', 'BUf']],
#   'Board': None,
#   'Players': [['SB', '', 113, ('5c', 'Ts')],
#               ['BB', 'Hero', 50, ('Kc', 'Ah')],
#               ['UTG', '', 115, ('Qh', '2s')],
#               ['LJ', '', 135, ('5h', 'Ad')],
#               ['HJ', '', 82, ('4d', '9d')],
#               ['BU', '', 109, ('9c', 'Ks')]],
#   'Stakes': (0.02, 0.05),
#   'WTSD': True,
#   'Winner': ['BB', None]},
#  {'Action': [['UTGr5', 'LJf', 'HJf', 'BUr54', 'SBf', 'BBb24', 'UTGc49']],
#   'Board': None,
#   'Players': [['SB', '', 86, ('8h', 'Qc')],
#               ['BB', '', 25, ('Qh', 'Kc')],
#               ['UTG', '', 87, ('8d', '8c')],
#               ['LJ', '', 100, ('7c', '2h')],
#               ['HJ', '', 134, ('3d', '2d')],
#               ['BU', 'Hero', 54, ('Js', 'Jd')]],
#   'Stakes': (0.02, 0.05),
#   'WTSD': True,
#   'Winner': [None, 'BU', 'BU']},
#  {'Action': [['UTGr49', 'LJf', 'HJf', 'BUf', 'SBf', 'BBf']],
#   'Board': None,
#   'Players': [['HJ', '', 121, ('Kh', '8c')],
#               ['BU', '', 43, ('6h', '7d')],
#               ['SB', '', 100, ('7h', '2h')],
#               ['BB', '', 100, ('Kd', '5d')],
#               ['UTG', 'Hero', 49, ('8s', '8h')],
#               ['LJ', '', 76, ('Js', 'Th')]],
#   'Stakes': (0.02, 0.05),
#   'WTSD': True,
#   'Winner': ['UTG']},
#  {'Action': [['UTGf', 'LJf', 'HJf', 'BUr51', 'SBf', 'BBf']],
#   'Board': None,
#   'Players': [['HJ', '', 107, ('3c', '9s')],
#               ['BU', 'Hero', 51, ('Tc', 'Td')],
#               ['SB', '', 98, ('Ad', '3d')],
#               ['BB', '', 136, ('4h', '2c')],
#               ['UTG', '', 82, ('8h', 'Kd')],
#               ['LJ', '', 75, ('7d', '4c')]],
#   'Stakes': (0.02, 0.05),
#   'WTSD': True,
#   'Winner': ['BU']},
#  {'Action': [['UTGf', 'LJf', 'HJr52', 'BUf', 'SBf', 'BBf']],
#   'Board': None,
#   'Players': [['HJ', 'Hero', 52, ('Ad', 'Td')],
#               ['BU', '', 207, ('2h', 'Ks')],
#               ['SB', '', 101, ('Ts', '2s')],
#               ['BB', '', 115, ('4s', 'Tc')],
#               ['UTG', '', 66, ('9d', '7s')],
#               ['LJ', '', 24, ('9c', '4c')]],
#   'Stakes': (0.02, 0.05),
#   'WTSD': True,
#   'Winner': ['HJ']},
#  {'Action': [['UTGf', 'LJr48', 'HJf', 'BUf', 'SBf', 'BBf']],
#   'Board': None,
#   'Players': [['BB', '', 521, ('8d', 'Jh')],
#               ['UTG', '', 110, ('2s', 'Qh')],
#               ['LJ', 'Hero', 48, ('9s', '9d')],
#               ['HJ', '', 55, ('5d', 'Qd')],
#               ['BU', '', 138, ('7d', '7h')],
#               ['SB', '', 119, ('6d', 'As')]],
#   'Stakes': (0.02, 0.05),
#   'WTSD': True,
#   'Winner': ['LJ']},
#  {'Action': [['UTGf', 'LJf', 'HJf', 'BUr47', 'SBf', 'BBf']],
#   'Board': None,
#   'Players': [['BU', 'Hero', 47, ('Ah', 'Js')],
#               ['SB', '', 53, ('Kd', '3h')],
#               ['BB', '', 100, ('8d', '3d')],
#               ['UTG', '', 108, ('Jh', '2c')],
#               ['LJ', '', 262, ('5s', '6h')],
#               ['HJ', '', 45, ('6s', '8s')]],
#   'Stakes': (0.02, 0.05),
#   'WTSD': True,
#   'Winner': ['BU', None]},
#  {'Action': [['UTGf', 'LJr3', 'HJr47', 'BUf', 'SBf', 'BBf', 'LJf']],
#   'Board': None,
#   'Players': [['HJ', 'Hero', 47, ('Ac', 'Jh')],
#               ['BU', '', 94, ('5s', 'Jc')],
#               ['SB', '', 94, ('3h', '3d')],
#               ['BB', '', 98, ('7h', 'Kc')],
#               ['UTG', '', 113, ('6c', '6d')],
#               ['LJ', '', 100, ('Js', '8s')]],
#   'Stakes': (0.02, 0.05),
#   'WTSD': True,
#   'Winner': ['HJ', None]},
#  {'Action': [['UTGf', 'LJf', 'HJf', 'BUf', 'SBr51', 'BBf']],
#   'Board': None,
#   'Players': [['SB', 'Hero', 51, ('Ad', 'As')],
#               ['BB', '', 50, ('Qs', '2d')],
#               ['UTG', '', 146, ('6h', '5d')],
#               ['LJ', '', 190, ('9s', 'Kd')],
#               ['HJ', '', 169, ('4d', 'Jc')],
#               ['BU', '', 149, ('Ks', '7h')]],
#   'Stakes': (0.02, 0.05),
#   'WTSD': True,
#   'Winner': ['SB', None]},
#  {'Action': [['UTGf', 'LJf', 'HJr2', 'BUr50', 'SBf', 'BBf', 'HJc48']],
#   'Board': None,
#   'Players': [['HJ', '', 154, ('6h', '6s')],
#               ['BU', 'Hero', 50, ('As', 'Ts')],
#               ['SB', '', 80, ('6c', '3d')],
#               ['BB', '', 36, ('Jc', '4s')],
#               ['UTG', '', 27, ('5s', '9d')],
#               ['LJ', '', 49, ('7d', '9s')]],
#   'Stakes': (0.02, 0.05),
#   'WTSD': True,
#   'Winner': ['BU']},
#  {'Action': [['UTGr49', 'LJf', 'HJf', 'BUr92', 'SBf', 'BBf']],
#   'Board': None,
#   'Players': [['UTG', 'Hero', 49, ('Jh', 'Jd')],
#               ['LJ', '', 100, ('8d', '4h')],
#               ['HJ', '', 36, ('Qs', '3c')],
#               ['BU', '', 92, ('9h', '9s')],
#               ['SB', '', 45, ('5s', 'Kh')],
#               ['BB', '', 100, ('9c', '7c')]],
#   'Stakes': (0.02, 0.05),
#   'WTSD': True,
#   'Winner': ['BU']},
#  {'Action': [['UTGf', 'LJr4', 'HJf', 'BUf', 'SBr46', 'BBf', 'LJc43']],
#   'Board': None,
#   'Players': [['HJ', '', 83, ('8c', '3h')],
#               ['BU', '', 138, ('4s', '2s')],
#               ['SB', 'Hero', 47, ('Ad', 'Th')],
#               ['BB', '', 101, ('Ts', '8d')],
#               ['UTG', '', 108, ('2c', 'As')],
#               ['LJ', '', 50, ('Js', 'Qs')]],
#   'Stakes': (0.02, 0.05),
#   'WTSD': True,
#   'Winner': ['LJ']},
#  {'Action': [['UTGc1', 'LJf', 'HJr4', 'BUf', 'SBr50', 'BBf', 'UTGf', 'HJf']],
#   'Board': None,
#   'Players': [['SB', 'Hero', 50, ('As', 'Kd')],
#               ['BB', '', 44, ('5h', '2s')],
#               ['UTG', '', 50, ('7s', 'Ks')],
#               ['LJ', '', 105, ('7h', 'Qd')],
#               ['HJ', '', 205, ('6s', '6c')],
#               ['BU', '', 82, ('4s', 'Js')]],
#   'Stakes': (0.02, 0.05),
#   'WTSD': True,
#   'Winner': [None, 'SB']},
#  {'Action': [['UTGf', 'LJf', 'HJr3', 'BUf', 'SBr55', 'BBf', 'HJf']],
#   'Board': None,
#   'Players': [['BU', '', 100, ('Jh', '2d')],
#               ['SB', 'Hero', 56, ('Ks', 'Js')],
#               ['BB', '', 114, ('2h', 'Ts')],
#               ['UTG', '', 113, ('9c', 'Th')],
#               ['LJ', '', 100, ('2s', 'Td')],
#               ['HJ', '', 589, ('6c', '5c')]],
#   'Stakes': (0.02, 0.05),
#   'WTSD': True,
#   'Winner': ['SB', None]},
#  {'Action': [['UTGr3', 'LJr47', 'HJf', 'BUf', 'SBf', 'BBf', 'UTGc44']],
#   'Board': ['Qc', '8h', 'Jd', '3d', '9s'],
#   'Players': [['LJ', 'Hero', 47, ('Qs', 'Ac')],
#               ['HJ', '', 103, ('6h', 'Jc')],
#               ['BU', '', 79, ('5h', '5d')],
#               ['SB', '', 35, ('Jh', '4c')],
#               ['BB', '', 76, ('7c', '6c')],
#               ['UTG', '', 99, ('Kh', 'As')]],
#   'Stakes': (0.02, 0.05),
#   'WTSD': True,
#   'Winner': ['LJ', None]}]

# %%
neat_vpip_hands = set(())
for hand in hero_vpip_hands:
    if(hand[0][0] == hand[1][0]):
        neat_vpip_hands.add(hand[0][0]*2)
    else:
        if(hand[0][1] == hand[1][1]):
            neat_vpip_hands.add(hand[0][0]+hand[1][0]+"s")
        else:
            neat_vpip_hands.add(hand[0][0]+hand[1][0]+"o")
hero_vpip_range = poker.Range(" ".join(neat_vpip_hands))

# %%
display(HTML(hero_vpip_range.to_html()))
# Out:
# <table class="range"><tr><td class="pair">AA</td><td class="suited">AKs</td><td class="suited">AQs</td><td class="suited">AJs</td><td class="suited">ATs</td><td class="suited">A9s</td><td class="suited">A8s</td><td class="suited">A7s</td><td class="suited">A6s</td><td class="suited">A5s</td><td class="suited">A4s</td><td class="suited">A3s</td><td class="suited">A2s</td></tr><tr><td class="offsuit">AKo</td><td class="pair">KK</td><td class="suited">KQs</td><td class="suited">KJs</td><td class="suited">KTs</td><td class="suited"></td><td class="suited"></td><td class="suited"></td><td class="suited"></td><td class="suited"></td><td class="suited"></td><td class="suited"></td><td class="suited"></td></tr><tr><td class="offsuit">AQo</td><td class="offsuit">KQo</td><td class="pair">QQ</td><td class="suited">QJs</td><td class="suited"></td><td class="suited"></td><td class="suited"></td><td class="suited"></td><td class="suited"></td><td class="suited"></td><td class="suited"></td><td class="suited"></td><td class="suited"></td></tr><tr><td class="offsuit">AJo</td><td class="offsuit">KJo</td><td class="offsuit"></td><td class="pair">JJ</td><td class="suited"></td><td class="suited"></td><td class="suited"></td><td class="suited"></td><td class="suited"></td><td class="suited"></td><td class="suited"></td><td class="suited"></td><td class="suited"></td></tr><tr><td class="offsuit">ATo</td><td class="offsuit"></td><td class="offsuit"></td><td class="offsuit"></td><td class="pair">TT</td><td class="suited"></td><td class="suited"></td><td class="suited"></td><td class="suited"></td><td class="suited"></td><td class="suited"></td><td class="suited"></td><td class="suited"></td></tr><tr><td class="offsuit"></td><td class="offsuit"></td><td class="offsuit"></td><td class="offsuit"></td><td class="offsuit"></td><td class="pair">99</td><td class="suited"></td><td class="suited"></td><td class="suited"></td><td class="suited"></td><td class="suited"></td><td class="suited"></td><td class="suited"></td></tr><tr><td class="offsuit"></td><td class="offsuit"></td><td class="offsuit"></td><td class="offsuit"></td><td class="offsuit"></td><td class="offsuit"></td><td class="pair">88</td><td class="suited"></td><td class="suited"></td><td class="suited"></td><td class="suited"></td><td class="suited"></td><td class="suited"></td></tr><tr><td class="offsuit"></td><td class="offsuit"></td><td class="offsuit"></td><td class="offsuit"></td><td class="offsuit"></td><td class="offsuit"></td><td class="offsuit"></td><td class="pair">77</td><td class="suited"></td><td class="suited"></td><td class="suited"></td><td class="suited"></td><td class="suited"></td></tr><tr><td class="offsuit"></td><td class="offsuit"></td><td class="offsuit"></td><td class="offsuit"></td><td class="offsuit"></td><td class="offsuit"></td><td class="offsuit"></td><td class="offsuit"></td><td class="pair">66</td><td class="suited"></td><td class="suited"></td><td class="suited"></td><td class="suited"></td></tr><tr><td class="offsuit"></td><td class="offsuit"></td><td class="offsuit"></td><td class="offsuit"></td><td class="offsuit"></td><td class="offsuit"></td><td class="offsuit"></td><td class="offsuit"></td><td class="offsuit"></td><td class="pair">55</td><td class="suited"></td><td class="suited"></td><td class="suited"></td></tr><tr><td class="offsuit"></td><td class="offsuit"></td><td class="offsuit"></td><td class="offsuit"></td><td class="offsuit"></td><td class="offsuit"></td><td class="offsuit"></td><td class="offsuit"></td><td class="offsuit"></td><td class="offsuit"></td><td class="pair">44</td><td class="suited"></td><td class="suited"></td></tr><tr><td class="offsuit"></td><td class="offsuit"></td><td class="offsuit"></td><td class="offsuit"></td><td class="offsuit"></td><td class="offsuit"></td><td class="offsuit"></td><td class="offsuit"></td><td class="offsuit"></td><td class="offsuit"></td><td class="offsuit"></td><td class="pair">33</td><td class="suited"></td> ...

# %%
def _get_caller_hand(players, pos):
    for player in players:
        if(player[0] == pos):
            return player[3]


def get_villian_vpip_hands_against_shove(hands):
    villian_vpip_range = set(())
    villian_vpip_hands = []
    
    for hand in hands:
        post_shove = False
        hero_pos = _get_hero_pos(hand["Players"])
        for action in hand['Action'][0]:
            if hero_pos + 'r' in action:
                post_shove = True
            if post_shove and 'c' in action:
                pos = action.split('c')[0]
                villian_vpip_hands.append(hand)
                villian_vpip_range.add(_get_caller_hand(hand['Players'], pos))

    return (villian_vpip_range, villian_vpip_hands)

villian_vpip, villian_vpip_hands = get_villian_vpip_hands_against_shove(hero_vpip)

# %%
def _create_neat_range(set_of_hands):
    neat_set = set(())
    for hand in set_of_hands:
        if(ord(hand[0][0]) < ord(hand[1][0])):
            if(hand[0][1] == hand[1][1]):
                neat_set.add(hand[1][0] + hand[0][0] + "s")
            else:
                neat_set.add(hand[1][0] + hand[0][0] + "o")
        elif(ord(hand[0][0]) > ord(hand[1][0])):
            if(hand[0][1] == hand[1][1]):
                neat_set.add(hand[0][0] + hand[1][0] + "s")
            else:
                neat_set.add(hand[0][0] +hand[1][0] + "o")
        else:
            neat_set.add(hand[0][0]*2)
    return neat_set
        
                
    
neat_vpip_hands = _create_neat_range(villian_vpip)
villan_neat_vpip_hands = poker.Range(" ".join(neat_vpip_hands))

display(HTML(villan_neat_vpip_hands.to_html()))
# Out:
# <table class="range"><tr><td class="pair">AA</td><td class="suited">AKs</td><td class="suited"></td><td class="suited"></td><td class="suited"></td><td class="suited">A9s</td><td class="suited"></td><td class="suited"></td><td class="suited">A6s</td><td class="suited">A5s</td><td class="suited">A4s</td><td class="suited"></td><td class="suited">A2s</td></tr><tr><td class="offsuit">AKo</td><td class="pair">KK</td><td class="suited">KQs</td><td class="suited"></td><td class="suited">KTs</td><td class="suited"></td><td class="suited"></td><td class="suited"></td><td class="suited"></td><td class="suited"></td><td class="suited"></td><td class="suited"></td><td class="suited"></td></tr><tr><td class="offsuit">AQo</td><td class="offsuit"></td><td class="pair">QQ</td><td class="suited">QJs</td><td class="suited"></td><td class="suited"></td><td class="suited"></td><td class="suited">Q7s</td><td class="suited"></td><td class="suited"></td><td class="suited"></td><td class="suited"></td><td class="suited"></td></tr><tr><td class="offsuit">AJo</td><td class="offsuit">KJo</td><td class="offsuit"></td><td class="pair">JJ</td><td class="suited"></td><td class="suited"></td><td class="suited"></td><td class="suited"></td><td class="suited"></td><td class="suited"></td><td class="suited"></td><td class="suited"></td><td class="suited"></td></tr><tr><td class="offsuit"></td><td class="offsuit"></td><td class="offsuit"></td><td class="offsuit"></td><td class="pair"></td><td class="suited">T9s</td><td class="suited"></td><td class="suited"></td><td class="suited"></td><td class="suited"></td><td class="suited"></td><td class="suited"></td><td class="suited"></td></tr><tr><td class="offsuit"></td><td class="offsuit"></td><td class="offsuit"></td><td class="offsuit"></td><td class="offsuit"></td><td class="pair">99</td><td class="suited"></td><td class="suited"></td><td class="suited"></td><td class="suited"></td><td class="suited"></td><td class="suited"></td><td class="suited"></td></tr><tr><td class="offsuit"></td><td class="offsuit"></td><td class="offsuit"></td><td class="offsuit"></td><td class="offsuit"></td><td class="offsuit"></td><td class="pair">88</td><td class="suited"></td><td class="suited"></td><td class="suited"></td><td class="suited"></td><td class="suited"></td><td class="suited"></td></tr><tr><td class="offsuit"></td><td class="offsuit"></td><td class="offsuit"></td><td class="offsuit"></td><td class="offsuit"></td><td class="offsuit"></td><td class="offsuit">87o</td><td class="pair">77</td><td class="suited"></td><td class="suited"></td><td class="suited"></td><td class="suited"></td><td class="suited"></td></tr><tr><td class="offsuit"></td><td class="offsuit"></td><td class="offsuit"></td><td class="offsuit"></td><td class="offsuit"></td><td class="offsuit"></td><td class="offsuit"></td><td class="offsuit"></td><td class="pair">66</td><td class="suited"></td><td class="suited"></td><td class="suited"></td><td class="suited"></td></tr><tr><td class="offsuit"></td><td class="offsuit"></td><td class="offsuit"></td><td class="offsuit"></td><td class="offsuit"></td><td class="offsuit"></td><td class="offsuit"></td><td class="offsuit"></td><td class="offsuit"></td><td class="pair"></td><td class="suited"></td><td class="suited"></td><td class="suited"></td></tr><tr><td class="offsuit">A4o</td><td class="offsuit"></td><td class="offsuit"></td><td class="offsuit"></td><td class="offsuit"></td><td class="offsuit"></td><td class="offsuit"></td><td class="offsuit"></td><td class="offsuit"></td><td class="offsuit"></td><td class="pair">44</td><td class="suited"></td><td class="suited"></td></tr><tr><td class="offsuit"></td><td class="offsuit"></td><td class="offsuit"></td><td class="offsuit"></td><td class="offsuit"></td><td class="offsuit"></td><td class="offsuit"></td><td class="offsuit"></td><td class="offsuit"></td><td class="offsuit"></td><td class="offsuit"></td><td class="pair"></td><td class="suited"></td></tr><tr><td class="o ...

# %%
print(villan_neat_vpip_hands)
# Out:
# JJ+, 99-66, 44, AKs, A9s, A6s-A4s, A2s, KQs, KTs, QJs, Q7s, T9s, AJo+, A4o, A2o, KJo, 87o

# %%
print(len(hero_vpip))
# Out:
# 232

# %%
def _get_caller_stack_size(players, pos):
    for player in players:
        if(player[0] == pos):
            return player[2]

def find_v_stack_size(hands):
    v_stack_hand = []
    for hand in hands:
        post_shove = False
        hero_pos = _get_hero_pos(hand["Players"])
        for action in hand['Action'][0]:
            if hero_pos + 'r' in action:
                post_shove = True
            if post_shove and 'c' in action:
                pos = action.split('c')[0]
                v_stack_hand.append((_get_caller_hand(hand['Players'], pos),  _get_caller_stack_size(hand['Players'], pos)))
    return v_stack_hand

v_stack_hand = find_v_stack_size(villian_vpip_hands)

v_hand_low_stack = []
v_hand_high_stack = []
for i in v_stack_hand:
    if(i[1] > 75):
        v_hand_high_stack.append(i[0])
    else:
        v_hand_low_stack.append(i[0])

v_hand_low_stack = _create_neat_range(v_hand_low_stack)
v_hand_high_stack = _create_neat_range(v_hand_high_stack)

# %%
display(HTML(poker.Range(" ".join(v_hand_high_stack)).to_html()))
# Out:
# <table class="range"><tr><td class="pair">AA</td><td class="suited">AKs</td><td class="suited"></td><td class="suited"></td><td class="suited"></td><td class="suited">A9s</td><td class="suited"></td><td class="suited"></td><td class="suited">A6s</td><td class="suited"></td><td class="suited"></td><td class="suited"></td><td class="suited">A2s</td></tr><tr><td class="offsuit">AKo</td><td class="pair">KK</td><td class="suited">KQs</td><td class="suited"></td><td class="suited">KTs</td><td class="suited"></td><td class="suited"></td><td class="suited"></td><td class="suited"></td><td class="suited"></td><td class="suited"></td><td class="suited"></td><td class="suited"></td></tr><tr><td class="offsuit">AQo</td><td class="offsuit"></td><td class="pair">QQ</td><td class="suited"></td><td class="suited"></td><td class="suited"></td><td class="suited"></td><td class="suited">Q7s</td><td class="suited"></td><td class="suited"></td><td class="suited"></td><td class="suited"></td><td class="suited"></td></tr><tr><td class="offsuit"></td><td class="offsuit">KJo</td><td class="offsuit"></td><td class="pair">JJ</td><td class="suited"></td><td class="suited"></td><td class="suited"></td><td class="suited"></td><td class="suited"></td><td class="suited"></td><td class="suited"></td><td class="suited"></td><td class="suited"></td></tr><tr><td class="offsuit"></td><td class="offsuit"></td><td class="offsuit"></td><td class="offsuit"></td><td class="pair"></td><td class="suited">T9s</td><td class="suited"></td><td class="suited"></td><td class="suited"></td><td class="suited"></td><td class="suited"></td><td class="suited"></td><td class="suited"></td></tr><tr><td class="offsuit"></td><td class="offsuit"></td><td class="offsuit"></td><td class="offsuit"></td><td class="offsuit"></td><td class="pair"></td><td class="suited"></td><td class="suited"></td><td class="suited"></td><td class="suited"></td><td class="suited"></td><td class="suited"></td><td class="suited"></td></tr><tr><td class="offsuit"></td><td class="offsuit"></td><td class="offsuit"></td><td class="offsuit"></td><td class="offsuit"></td><td class="offsuit"></td><td class="pair">88</td><td class="suited"></td><td class="suited"></td><td class="suited"></td><td class="suited"></td><td class="suited"></td><td class="suited"></td></tr><tr><td class="offsuit"></td><td class="offsuit"></td><td class="offsuit"></td><td class="offsuit"></td><td class="offsuit"></td><td class="offsuit"></td><td class="offsuit">87o</td><td class="pair">77</td><td class="suited"></td><td class="suited"></td><td class="suited"></td><td class="suited"></td><td class="suited"></td></tr><tr><td class="offsuit"></td><td class="offsuit"></td><td class="offsuit"></td><td class="offsuit"></td><td class="offsuit"></td><td class="offsuit"></td><td class="offsuit"></td><td class="offsuit"></td><td class="pair">66</td><td class="suited"></td><td class="suited"></td><td class="suited"></td><td class="suited"></td></tr><tr><td class="offsuit"></td><td class="offsuit"></td><td class="offsuit"></td><td class="offsuit"></td><td class="offsuit"></td><td class="offsuit"></td><td class="offsuit"></td><td class="offsuit"></td><td class="offsuit"></td><td class="pair"></td><td class="suited"></td><td class="suited"></td><td class="suited"></td></tr><tr><td class="offsuit">A4o</td><td class="offsuit"></td><td class="offsuit"></td><td class="offsuit"></td><td class="offsuit"></td><td class="offsuit"></td><td class="offsuit"></td><td class="offsuit"></td><td class="offsuit"></td><td class="offsuit"></td><td class="pair">44</td><td class="suited"></td><td class="suited"></td></tr><tr><td class="offsuit"></td><td class="offsuit"></td><td class="offsuit"></td><td class="offsuit"></td><td class="offsuit"></td><td class="offsuit"></td><td class="offsuit"></td><td class="offsuit"></td><td class="offsuit"></td><td class="offsuit"></td><td class="offsuit"></td><td class="pair"></td><td class="suited"></td></tr><tr><td class="offsuit">A2o</t ...
